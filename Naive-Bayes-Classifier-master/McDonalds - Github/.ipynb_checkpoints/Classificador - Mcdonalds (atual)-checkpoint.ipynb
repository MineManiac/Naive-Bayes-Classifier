# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Matheus Barros
#
# Nome: Giulia Sampaio
#
# **Atenção:** Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import re
import math

# %% [markdown]
# **Em `filename`, coloque o nome do seu arquivo de dados!**

# %%
import os

filename = 'mcdonalds.xlsx'
if filename in os.listdir():
    print(f'Encontrei o arquivo {filename}, tudo certo para prosseguir com a prova!')
else:
    print(f'Não encontrei o arquivo {filename} aqui no diretório {os.getcwd()}, será que você não baixou o arquivo?')
# Out:
# Encontrei o arquivo mcdonalds.xlsx, tudo certo para prosseguir com a prova!

# %% [markdown]
# Carregando a base de dados com os tweets classificados como relevantes e não relevantes:

# %%
train = pd.read_excel(filename)
train.head(5)
# Out:
#                                          Treinamento  Categorias
# 0  por isso eu prefiro o @mcdonalds_br https://t....           3
# 1  queria comer uma besteirinha, tipo um big tast...           3
# 2  @sergiosepsep @mcdonalds_br @ifood eu já tive ...           2
# 3                 @mvmarizinha @mcdonalds_br mentira           0
# 4  fui no @mcdonalds_br do @rapososhopping e fiz ...           4

# %%
test = pd.read_excel(filename, sheet_name = 'Teste')
test.head(5)
# Out:
#                                                Teste  Categorias
# 0  @mcdonalds_br tenho que me sujeitar a essas co...           4
# 1                      pq o @mcdonalds_br  e tão bom           3
# 2            @mcdonalds_br cadê o lanche do travis ?           2
# 3  @laiz_izabeli @mcdonalds_br da o combo todo po...           3
# 4  @jonitd_ @mcdonalds_br isso era pra ser um che...           3

# %% [markdown]
# ___
# ## Classificador automático de sentimento

# %% [markdown]
# Faça aqui uma descrição do seu produto e o que considerou como relevante ou não relevante na classificação dos tweets.
#
# **Analisar a opinião dos usuários a respeito da rede de fastfood mcdonald's, levando em conta as experiências do usuário.**
#
# * (0) Muito Irrelevante - Um tweet que não reflete nada a respeito da opinião do usuário em relação ao mcdonalds.
#
# * (1) Irrelevante - Um tweet que felita a opinião do usuário, mas pouco.
#
# * (2) Neutro - Um tweet que não tenha defeitos nem qualidades, ou estão em equilíbrio.
#
# * (3) Relevante - Tem uma opinião, boa ou ruim.
#
# * (4) Muito Relevante - Tem uma opinião que reflita muito a imagem do Mcdonalds, boa ou ruim.

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
train.Categorias = train.Categorias.astype('category')
test.Categorias = test.Categorias.astype('category')

train.Categorias.cat.categories = ['Muito Irrelevante', 'Irrelevante', 'Neutro', 'Relevante', 'Muito Relevante']
test.Categorias.cat.categories = ['Muito Irrelevante', 'Irrelevante', 'Neutro', 'Relevante', 'Muito Relevante']

train.head()
# Out:
#                                          Treinamento         Categorias
# 0  por isso eu prefiro o @mcdonalds_br https://t....          Relevante
# 1  queria comer uma besteirinha, tipo um big tast...          Relevante
# 2  @sergiosepsep @mcdonalds_br @ifood eu já tive ...             Neutro
# 3                 @mvmarizinha @mcdonalds_br mentira  Muito Irrelevante
# 4  fui no @mcdonalds_br do @rapososhopping e fiz ...    Muito Relevante

# %%
train.Categorias.value_counts()
# Out:
# Muito Irrelevante    373
# Relevante            139
# Muito Relevante       89
# Neutro                89
# Irrelevante           60
# Name: Categorias, dtype: int64

# %%
train.Categorias.value_counts(True)
# Out:
# Muito Irrelevante    0.497333
# Relevante            0.185333
# Muito Relevante      0.118667
# Neutro               0.118667
# Irrelevante          0.080000
# Name: Categorias, dtype: float64

# %%
def cleanup(text):

    """
    Função de limpeza muito simples que troca alguns sinais básicos por espaços
    """

    #import string

    punctuation = '[!-.:?\;_$%,]' # Note que os sinais [] são delimitadores de um conjunto.
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, '', text)
    link_sub = re.sub(r'http[^\s]*', '', text_subbed)
    #@[^\s]*

    return link_sub

# %%
train_cleanup = []

for row in train.Treinamento:
    row = cleanup(row)
    train_cleanup.append(row)
    
train_cleanup
# Out:
# ['por isso eu prefiro o @mcdonaldsbr ',
#  'queria comer uma besteirinha tipo um big tasty do @mcdonaldsbr  🤤',
#  '@sergiosepsep @mcdonaldsbr @ifood eu já tive problemas com o pedido do mc mas foi pelo ubereats liguei no ubereats fiz a reclamação e eles estornaram o valor no meu cartão tudo isso em menos de 5 min 🙏🏻 ninguém merece ficar puto com o pedido qdo chega e ainda levar canseira depois disso',
#  '@mvmarizinha @mcdonaldsbr mentira',
#  'fui no @mcdonaldsbr do @rapososhopping e fiz meu pedido quando pedi guardanapo a gerente isso mesmo extremamente grossa virou as costas e me deixou falando até nunca mais',
#  'rt @thia6o0 @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil sim nunca percebeu as mensagens ocultas na logo ',
#  'rt @rap24horasblog combo do travis scott no mcdonald’s faz enorme sucesso e esgota ingredientes do fast food  via @…',
#  '@mvmarizinha @mcdonaldsbr sério kkkkkkkkkkkkkkkkkk',
#  '@mcdonaldsbr @jamesdeliverybr favor voltem com  o refrigerante em lata que saco toda vez vem derramado metade do refrigerante e da ultima vez o refri ainda deu um banho na batata que saco',
#  'olá @mcdonaldsbr o @luansantana está há procura de empresas pra apoiálo em uma live em prol do pantanal que tal abraçar essa ideia\n\nluan pelo pantanal',
#  '@jotabarber @jpsantana09 mais conhecido como @mcdonaldsbr',
#  'a felicidade que um @mcdonaldsbr proporciona hahahahaha novafotodoperfil ',
#  '@lauras @mcdonaldsbr desejei',
#  'como me explicar @mcdonaldsbr pode existir molhos big mac picanha e bacon invisível ',
#  '@mcdonaldsbr @fepaesleme domingo passado  dia 13/09 comprei 3 bicmac e paguei para ter hambúrguer em dobro quando cheguei em casa abri o pacote dos lanches  sem as carnes extras o e nem esse potãofui roubado  na loja da vmatilde  radial lesteminha experiência constrangedora e péssimo lanche',
#  '@affonsoju @steviveiros @mcdonaldsbr e eu só queria um giga tasty mano',
#  '@bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil vai procurar um psiquiatra lunático kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk',
#  'queria era tá comendo um @mcdonaldsbr',
#  '@rkteixeira7 @mcdonaldsbr ta achando q tu é o travor escotix seu fdp',
#  'tá de sacanagem né @mcdonaldsbr  ',
#  '@nowornevergbye @claunutri4 @ograndepensado2 @josefer70649021 @mcdonaldsbr @fepaesleme gado socializado socializando com amigos bonita sua atitude',
#  '@sennadobone @oestagiariodoei @casimiro @mcdonaldsbr patrocina os cara aí po',
#  '@baamarcal @mcdonaldsbr @ifood pois é essa embalagem é pra pedido no balcão agora eu penso o tanto de copo que não chegou tombado assim ',
#  '@mcdonaldsbr vocês cederam a pressão da sleeping giants  ok eu já tinha boicotado o bk é bom que agora só como the fifities vou ficar snob kkkkkkkk',
#  '@alvesmaiira @mcdonaldsbr eita  assim que eu provar dou minha opinião',
#  '@oiiuiz @mcdonaldsbr chupa mequi ',
#  'na frente da loja que tô trabalhando hoje tem um @burgerkingbr e um @mcdonaldsbr e a dúvida de qual ir dps do job só pra tomar um sorvetinho ',
#  '@fabiocatena @mcdonaldsbr @uberbrasil sentimos em saber que o pedido não chegou como esperava \n oras que bobagem eu esperava mesmo não receber fiquei muito satisfeito parabéns pelo excelente serviço vou até favoritar e dar gorjeta',
#  '@leozabotto eita vem conversar com a gente na dm queremos te ajudar',
#  '@mcdonaldsbr de pelotas tô esperando o lanche do travis scott favor lançar pra nós',
#  'e mais uma feita de trouxa pelo @mcdonaldsbr com papel no lanche última chance que dei p esse estabelecimento que diz ser padronizado segundo o email que recebi único retorno que tive ',
#  '@1dpsychic @mcdonalds @mcdonaldsbr bora nego fazer um milkshake com o nome do patrão ',
#  '@rogersouza96 @mcdonaldsbr já tava mordido q veio sem batata do nada brotam aqui com mais😂',
#  'acordei com vontade de comer cbo  alo @mcdonaldsbr demorou pra voltar ele definitivo pro cardápio',
#  'rt @domdasthreads bom dia @mcdonaldsbr tudo bem\nficamos sabendo que vcs apoiam o comunismo aquela ideologia nefasta que torturou e mato…',
#  '@mcdonaldsbr esse é o padrão agora dos lanches ',
#  '@zanettils @mcdonaldsbr kkkkkkkkkkkkkkk eu fui buscar uma maionese na cozinha pq ta seco seco seco sem brincadeira alguma',
#  '@zeppelinfour mds siim eu com certeza assino e apoio o milkshake larry aaaaaa\n\n@mcdonaldsbr vc tá perdendo money podia ter o milkshake larry 💅',
#  'rt @drikarg1 @oiiuiz @mcdonaldsbr olha não sou tão inteligente e como boa tia do zap caio nas bait do povo kkkkk\n\nmas nesse momento len…',
#  '@slpnggiantspt @mcdonaldsbr mcdonald´s faça um favor suma do brasil ',
#  'orgulho do luan um exemplo \nque dê tudo certo 🙏🏼❤\n\nluan pelo pantanal\n\n@cocacolabr \n@americanascom \n@skol \n@amstelbrasil\n@multishow\n@picpay\n@lojasrenner\n@mcdonaldsbr\n@burgerkingbr\n@brahmacerveja \n@amazonbr \n@nike \n@adidasbrasil\n@nestleninho \n@fanta\n@redeglobo ',
#  'rt @flaviogordon @mcdonaldsbr @slpnggiantspt @youtubebrasil vocês conhecem o obscuro perfil “sleeping giants” tratase de um perfil qu…',
#  'alô @mcdonaldsbr corre aqui estou definindo pessoas baseados nos lanches mereço reconhecimento do mequi',
#  'uai @mcdonaldsbr acabou hambúrguer de vocês ',
#  'empresas como @uberbrasil @ifood @mcdonaldsbr entre outros empinando o rabo para perfil anônimo que manipula o mercado em nome da democracia\n\nempresas mequetrefes não importa mais o que faça @slpnggiantspt não vão derrotar o consevadorismo',
#  'mike me mandou a campanha de @mcdonaldsbr \nlogo mais verei',
#  '@mcdonaldsbr  e @ifood  estão de parabéns reclamei do pedido péssimo que veio do mc pois tudo estava gelado e duro e eles se prontificaram e mandaram outro delicioso parabéns',
#  '@mcdonaldsbr @fepaesleme beleza mas cade o travis meal',
#  'eu tô numa de comer mc que só a misericórdia de deus só queria q me patrocinasse @mcdonaldsbr',
#  '@mmaglobal c/ @wazebrasil @mcdonaldsbr @agenciadpzt  transformando a experiência do consumidor através da inovação 🤝',
#  'se liga @mcdonaldsbr kd o lanche do travis ',
#  'oii @mcdonaldsbr boa tarde o @luansantana está com um projeto para ajudar o pantanal há dois meses o projeto está pronto e a procura de patrocínio/apoio você poderia ajudar mesmo que seja um tweet sobre a causa já faria a diferença \n\no pantanal chama',
#  '@itzdeboraxxx @dhsouza6 @mcdonaldsbr vou ai vc só fica no telefone',
#  '@opredao @mcdonaldsbr  vão perder esse artista',
#  '@mcdonaldsbr faça alguma coisa 🙏🏻😭',
#  '@fabiocatena @mcdonaldsbr @uberbrasil engraçado uma vez não veio um item informei e já devolveram automaticamente o valor dele',
#  'totalmente inspirado nas dicas de receita da  @lariluana93 um recado para o @mcdonaldsbr cês tão frito na minha mão 😁😎 ',
#  '@tremmbarbie22 @mcdonaldsbr sextouuuu  só vamos ',
#  'pedi 2 big mac e 2 batatas média veio um tasty e uma batat grande \npoxa @mcdonaldsbr fiquei aguada no big mac',
#  '@mcdonaldsbr @fepaesleme pq vcs não fazem uma edição especial de verão e colocam açaí ou melhor deixa o açaí no cardápio',
#  '@mdregionalbr atenção vamos boicotar as seguintes empresas que caíram na lábia do grupo de extrema esquerda sleeping giants\ncasas bahia\npolishop\nmcdonalds\nifood\nnatura\npaypal\nágorainvestimentos\ndomestikabrasil\nhotmart\nbayerbrasil\ndellbrasil\nbudweiser\nuberbrasil',
#  '@jfaraujoura @fernando250164 @jornaldacidadeo @agoracorretora @casasbahia @polishop @mcdonaldsbr @ifood @naturabroficial @paypal @paypalbr @domestikabrasil @hotmart @brbayerbrasil @dellbrasil @budweiserbr @uberbrasil \ncomo pode se colocarem contra o povo e a favor de um grupo criminoso que só fazem mentir e manipular',
#  '@nicolyreporter @palmeirasso51 @mcdonaldsbr @ecxvpiracicaba ah hj sério pensei que era atleticana por causa de um ttb',
#  'o @mcdonaldsbr não mandou meu mc flurry no pedido e o moço do ifood não conseguiu falar com elesda próxima eu peço um king',
#  'oii @mcdonaldsbr bom diia  @luansantana está com um projeto para ajudar o pantanal há dois meses o projeto está pronto e a procura de patrocínio/apoio você poderia ajudar mesmo que seja um tweet sobre a causa já faria a diferença \n\no pantanal chama',
#  '@ifood tá dando mais não os mandam os trem tudo errado e não tem resposta rápida to com fome e não tenho tempo para sair para almoçar valeu também @mcdonaldsbr só faltou o sanduíche a coca e a batata brincadeira',
#  '@mcdonaldsbr vou eu tatuar a logo de vocês',
#  'meu sonho é receber um salário pra fazer um comercial do @mcdonaldsbr comendo um hamburguer',
#  'o travesseiro de 90 cm custa us 90 cerca de r 480 e já está esgotado  mcdonalds chickenmcnuggets',
#  '@luizgnribeiro @mcdonaldsbr tenho ódioooo smp eles esquecem',
#  '@gusobral @mcdonaldsbr quarteirão it’s lit 🤩',
#  '@nowornevergbye @claunutri4 @ograndepensado2 @josefer70649021 @mcdonaldsbr @fepaesleme qual a vaquinha ai recomenda',
#  'rio de janeiro 11/9/2020 loja do @mcdonaldsbr no centro da cidade é mcprotegidos que ces falam né se pro cliente tá assim imagina pros funcionários ',
#  'rt @ottokova @ailtonbenedito @ludmilagrilo @mcdonaldsbr se eu fosse algum lesado demandaria não somente contra o sleeping giants mas c…',
#  'não aguento mais cara toda vez que eu peço sundae do @mcdonaldsbr vem com amendoim ou com paçoca e eu sou alérgica o pior é que sempre boto na observação e sempre vem com tudo misturado e não consigo separar sério acho que ja foram umas 10 tentativas e nunca vem certo',
#  '@oiiuiz @mcdonaldsbr eu já não comia lá msm agora que não vou mais',
#  'pq uma água de 500ml está r650  @mcdonaldsbr  é de ouro  decepcionada',
#  '@mcdonaldsbr @pecesiqueira o preferido dele deve ser mc lanche feliz',
#  '@josefickk @xshamilx @mcdonaldsbr mas ai é um lanche que nem existe no br hahahahahaha eu não abriria app pra pedir mcdonalds nem aqui nem na china eu iria lá buscar',
#  '@itzdeboraxxx @dhsouza6 @mcdonaldsbr só chama ele pdc',
#  '@paulovieirareal @burgerkingbr @mcdonaldsbr não é só o publicitário que tem que ser ousado é a empresa que tem que aprovar o que geralmente não acontece',
#  '@mcdonaldsbr @slpnggiantspt @youtubebrasil nuca mais como numa porcaria dessa @mcdonaldsbr nem eu nem minha família além de ser uma comida muuuito cara pelo lanche q vem uma porcaria',
#  'eu fico admirado com essas pessoas que vão no @mcdonaldsbr e só comem um hambúrguer',
#  'rt @misscopa q campanha infeliz do @mcdonaldsbr eu olho pra cara feia da fernanda paes leme e o que menos já me dá vontade de fazer é co…',
#  'medo de pedi lanche no @mcdonaldsbr e vim errado pq e tanta reclamação que da medo kkkkk',
#  '@mcdonaldsbr solta um lanche vegetariano novo aí tiozao tá moscando',
#  '@nicolyreporter @palmeirasso51 @mcdonaldsbr a questão não é ele vim ou não kkkk a questão é que vc debocha das informações  eu não quero que vc apague seu tt só simplesmente procurar debater as informações  pois vc pode receber de uma fonte e as outras pessoas receberem de outras fontes',
#  'quero tanto um mc nifico bacon combo @mcdonaldsbr bora realizar o meu sonho',
#  'rt @a3agorah @slpnggiantspt @youtubebrasil @99food @casasbahia @domestikabrasil @polishop @naturabroficial @indriver @ifood @agoracorret…',
#  '@sorrywayland @mcdonaldsbr caramba aconteceu a mesma coisa comigo hoje surreal',
#  '@fmonteiro0 @devezze bora de mcdelivery que a gente resolve isso aí 🤭',
#  '@mcdonaldsbr  trás o lanche do travis pra nós pfvr',
#  'pedi fiz a personalização só falta o @mcdonaldsbr mandar errado',
#  'ticket de refeição renovou hoje já fui no @mcdonaldsbr fazer as compras hahaha',
#  '@happyyouare @danielmatador9 alô @mcdonaldsbr esquerdista defensor de perfil terrorista @slpnggiantspt\nvão tomar no olho do cu de vocês\n\n@mcdonalds your friends here from brazil are destroying your companys image by supporting leftwing terrorist profiles be alert',
#  'tiraram o mcfish de linha vsf @mcdonaldsbr',
#  'olá @mcdonaldsbr  bom dia o @luansantana está há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e nenhuma se prontificou que tal abraçar a ideia \n\nluan pelo pantanal',
#  '@mcdonaldsbr  tome providencias sobre isso pfv',
#  'q campanha infeliz do @mcdonaldsbr eu olho pra cara feia da fernanda paes leme e o que menos já me dá vontade de fazer é comer o q ela tá comendo  🤢🤮',
#  '@eliesaaab @mcdonaldsbr poderiam aderir isso dnv né',
#  '@vicksaraiva @mcdonaldsbr vamos reviver isso tem mcoferta clássica  mcflurry ou mcoferta clássica  cheeseburger para você curtir 😱🔥 é só clicar no link  ',
#  '@giterezzino @mcdonaldsbr mano que p é essa kkkkk que surreal',
#  '@brazilmulambo @burguerking1 @mcdonaldsbr cara meu favorito disparado sempre penso em pedir um diferente e acabo pedindo esse kkkk',
#  'eu to a muito tempo querendo comer o cbo do @mcdonaldsbr 😭',
#  'completamente indignada que tiraram o mc fish do cardápio \n\ndona @mcdonaldsbr qual é o seu problema',
#  '@thiagornp @burguerking1 @mcdonaldsbr também acho que está melhor aquele wopper furioso é foda',
#  '@deiapimentinha1 @mcdonaldsbr @slpnggiantspt @youtubebrasil ue agora que caiu a ficha se você tava se sentindo enganada devia ter parado comprar lanche de lá sem precisar ver esse comentário que não tem nada a ver com lanche',
#  'vai tomar no cu @burgerkingbr e @mcdonaldsbr comida lixo cheia porcaria\ncam\xadpanha pu\xadbli\xadci\xadtária pro\xadmo\xadvida em par\xadceria com as duas me\xadga\xadcor\xadpo\xadra\xadções mos\xadtram “ro\xadnald mc\xaddo\xadnald” e “king” em de\xadmons\xadtração ho\xadmos\xadse\xadxual 🤦🏻\u200d♂️😡 ',
#  '@cevapolar eu não quero patrocínio da @brahmacerveja nem do @mcdonaldsbr  quero patrocínio da @cevapolar',
#  '@nikolasdm só não vale comprar na @mcdonaldsbr',
#  'rt @slpnggiantspt o @mcdonaldsbr sabe que fake news traz má digestão a democracia e por isso desmonetizou o seu anúncio no canal do @yo…',
#  'olá @mcdonaldsbr o @luansantana tá há dois meses procurando marcas para apoialo em uma live pra ajudar o pantanal e nenhuma se prontificou que tal abraçar a ideia luan pelo pantanal',
#  'rt @revistaistoe o travesseiro de 90 cm custa us 90 cerca de r 480 e já está esgotado  mcdonalds chickenmcnu…',
#  '@isaahduarte @mcdonaldsbr aí é foda',
#  '@mdregionalbr @newberni atenção vamos boicotar as seguintes empresas que caíram na lábia do grupo de extrema esquerda sleeping giants\ncasas bahia\npolishop\nmcdonalds\nifood\nnatura\npaypal\nágorainvestimentos\ndomestikabrasil\nhotmart\nbayerbrasil\ndellbrasil\nbudweiser\nuberbrasil',
#  '@julysalino @mcdonaldsbr denver melhorou e virou o jogo jokic meteu umas bolas de 3 lindas',
#  '@fabiocatena @mcdonaldsbr @uberbrasil pqp que droga cara e a gente fica com cara de otario olhando pro celular “se vira ai”',
#  'rt @donareginaa @mcdonaldsbr @slpnggiantspt @youtubebrasil fodamse vocês com as merdas secas que vocês chamam de hambúrguer ',
#  'combo do travis scott no mcdonald’s faz enorme sucesso e esgota ingredientes do fast food  via @rap24horasblog',
#  '@pedrodelfabro @mcdonaldsbr acontece né',
#  '@mcdonaldsbr a humilhação do dia foi meu sanduíche vir mordido ',
#  '@bianadoces @mcdonaldsbr amg pelo menos não veio um formigão',
#  'mcdonald’s e aberje abrem inscrições para o projeto escalando o futuro\xa02020 ',
#  '@mvmarizinha @mcdonaldsbr me manda a foto kkkkk',
#  '@wxmadu poxa sentimos muito por isso chama a gente na dm',
#  '@lawnlyet @mcdonaldsbr mano kkkkk eu sou veganaporém essa thread foi muito sla',
#  '@marcesar25 @mcdonaldsbr @slpnggiantspt @youtubebrasil desoxirribonucleicamente  idem 🥳\neamém🙏🏻',
#  '@dhsouza6 @itzdeboraxxx @mcdonaldsbr de batata mala mais',
#  '@mcdonaldsbr @pecesiqueira @mcdonaldsbr apoia a pedofilia no brasil',
#  '@ficaacriterio nossa esse não é o nosso padrão chama a gente na dm vamos ajudar você',
#  '@bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil sim eles sao comunistas cheguei lá com uma blusa vermelha e disse nossos hamburgueres e peguei 5 comi e fui embora muito bom o comunismo haha\nvocê é um símio burro de merda',
#  '@mvmarizinha @mcdonaldsbr cade a foto kkkkkkkkkkkkkkkkkkkkkkk',
#  '@museudocinema @mcdonaldsbr será q ela sabe do q é feita a carne do mcdonalds',
#  'aqui em rio grande esperei meia hora no drive thru para saber que o veggie saiu do cardápio pedi batatas com cheddar sem bacon e recebi uns pingos de cheddar esse é o padrão @mcdonaldsbr além do atendimento que não tem bom dia boa tarde e boa noite @mcdonaldsbr ',
#  '@vitorialaris @mcdonaldsbr esse dia vai chegar po confia',
#  'rt @storyofluans oi @mcdonaldsbr\n@luansantana está há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e nenhu…',
#  'o @mcdonaldsbr não a maior rede de restaurantes do mundo a toa é entre outras coisas pelo relacionamento com o cliente\n\ndepois da palhaçada e do roubo do @uberbrasil eats o mc veio e resolveu o problema\n\nagradeço ao gerente anderson renovou minha carteirinha de mclover ',
#  '@domdasthreads @celsopereirado4 @mcdonaldsbr engraçado que é uma empresa do país mais capitalista do mundo\ndeveria mudar a matriz pra chinaseria perfeito ter que vender com preço tabelado pelo ditador chinês\n@mcdonaldsbr fica a dica😜',
#  '@mcdonaldsbr macdonaldsbr promove a censura ao aceitar a pressão de perfis fantasmas fiquem com o sleep giants para vender os seus produtos porque eu nunca mais comprarei produtos de vocês',
#  '@spiessantana oi @mcdonaldsbr o @luansantana tá há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e nenhuma se prontificou que tal abraçar a ideia \n\nluan pelo pantanal',
#  '@mcdonaldsbr faz o lanche do matue ai na moral',
#  'rt @paratiamarls oii @mcdonaldsbr bom diia  @luansantana está com um projeto para ajudar o pantanal há dois meses o projeto está pronto…',
#  'rt @ebuasls oi @mcdonaldsbr o cantor @luansantana está procurando parcerias para uma live com intuito de arrecadar doações para o pantan…',
#  '@70almeida @palmeirasso51 @mcdonaldsbr obrigada querido 😘',
#  '@oiiuiz @profpaulamarisa @mcdonaldsbr gordofobia não existe o que existe e gente esganada que acha que a comida vai acabar e ponto isso eu seieste dou eu',
#  'tudo começou a piorar depois que o @mcdonaldsbr parou de vender o cbo',
#  '@luizadlima @ifood vish chama a gente na dm pra podermos te ajudar',
#  'a propaganda do @mcdonaldsbr eh pra mim “saudade de um big mac né fê” hahahahaha comeria um agora saudade mesmo socorro @gabrielzanin15 ',
#  '@bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil carai ze tu ta chamando o mc donalds de esquerda \nkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk\n\ntu é a maio piada do br kkkkkkkkkkkkkkkkkkkkkkkkkkkkk',
#  '@fmonteiro0 @mcdonaldsbr alguma vovozinha online pra fazer',
#  'mcdonalds bó trazer o lanche do travis pro br',
#  '@paulovieirareal @burgerkingbr @mcdonaldsbr não quero agourar relacionamento de ninguém  mas dá pra notar que burguer tá mais apaixonado do que mcdonalds🙊',
#  '@anittaoffense @mcdonaldsbr vem em casa tem ainda',
#  '@paulovieirareal @burgerkingbr @mcdonaldsbr bk arregaça nas peças mesmo sempre',
#  'rt @fnxconservadora a vcs empresas q dão voz à agenda da esquerda progressista revolucionária comunista globalista e ainda tem ligação…',
#  '@podeisso4 @mcdonaldsbr @uberbrasil bom dia sugerimos que apresente a questão para apreciação da nossa diretoria de fiscalização caso resida no estado de são paulo acesse    clique na aba nova reclamação\npara encaminhar o problema solicitamos que\n1 faça o login ou cadastrese',
#  '@juliooathie @mcdonaldsbr não acho tenho certeza',
#  'parabéns a todos os gordos pelo dia do gordo tem promoção no @mcdonaldsbr hj se não deveria',
#  'vamos ajudar o pantanal  assine a petição  via @changebr',
#  '@rludhriq @riquelmesrn @mcdonaldsbr @pecesiqueira quem faz piada com assunto de pedofilia e estupro tem que tomar no cu e se foder muito nojento do caralho',
#  '@mcdonaldsbr eu quero o bonequinho do travis ok ',
#  '@mcdonaldsbr foi muito escroto vc cancelar a propaganda com o olavo de carvalho 😡😡😡',
#  '@danizinhawnx @mcdonaldsbr @ifood mandei foto e tudo mais e eles estornaram já mas a vontade de tomar um milkshake ficou hahaha',
#  '@mcdonaldsbr manda mimos por favor',
#  '@casasbahia @polishop\n@mcdonaldsbr @ifood\n@paypalbr @dell @uberbrasil\n@budweiserbr @bayer @agoracorretora @hotmart\n\nsleeping giants perfil anônimo q ataca perfis conservadores desrespeitando a democracia e liberdade de expressão \n\n',
#  '@mcdonaldsbr pq vocês estão tirando o top sundae de caramelo das lojas',
#  '@flaviogordon @mcdonaldsbr @slpnggiantspt @youtubebrasil observando aqui o que tem de conservador seguindo saporra aí sleeping giants🤔',
#  'com a celebração do orgulho em helsinque se aproximando o burger king decidiu declarar o seu amor pelo mcdonalds em sua nova campanha ',
#  '@anamnesias @danzo1989 @mcdonaldsbr agora entendi pq simpatizei com vc kkkkk',
#  '@feliperuizfr oie chama a gente na dm e conta melhor sobre o que aconteceu estamos te esperando',
#  '@flaviogordon @mcdonaldsbr @slpnggiantspt @youtubebrasil porque o marketing apinhado de publicitários esquerdistas recémformados manda mais na empresa do que quem deveria mandar',
#  '@bkpetta @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil @bhvinny paulo kogos estava correto eu te disse',
#  'duas maravilhas numa foto só pôr do sol e o melhor lugar @mcdonaldsbr ',
#  'rt @marcosfelipeb38 @oiiuiz @mcdonaldsbr mermão que gente chata a vida dessas pessoas deve ser infeliz demais e certamente não content…',
#  '@maeda1real @mcdonaldsbr @ifood já fiz faz tempo no ifood e no mc to  esperando resposta mas até agora nada',
#  'ae @mcdonaldsbr janta tava responsa fmlh 🍃✊🏻\U0001f9a7',
#  'eai @mcdonaldsbr manda um big mac de presente de presente aí nunca pedi nada mo vontade 🥺🙏🏼',
#  'e eu que fiz um pedido no sr @mcdonaldsbr e simplesmente a batata não chegou aiai akakak foi 12 conto 😭',
#  '@mcdonalds @mcdonaldsbr me patrocina quero um chicken jr é uma batata média',
#  'rt @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil oi mcdonalds vocês estão servindo a um canal que sequer uma pessoa tem a c…',
#  'e eu que tava bem e boas aqui pensando em fazer um lanche no @mcdonalds @mcdonaldsbr da rua 7 aqui em blumenau quando me deparo clássico do dia baixou de r790 pra r890 alôooooo @procon isso tá certo hsushsushhs queromcdegraça mcdonalds ',
#  '@gabilobato @mcdonaldsbr giraffas tá tendo e é um empanado gostosinho',
#  'no @mcdonaldsbr nao da kkkkkk sanduíche veio mordido to d cara',
#  '@mauroalveszl @opropriolavo @slpnggiantspt @timbrasil @ifood @mcdonaldsbr mas e o que falo não adianta ficar boicotando\neu até faço a minha  parte mas minha esposa que não  esta nem aí pra isso compra normal',
#  '@carolgrigori fala com o @mcdonaldsbr costumam ser bem atenciosos',
#  '@paulovieirareal @burgerkingbr @mcdonaldsbr mas o lanche do @mcdonaldsbr é 10/10',
#  '@vendezap @slpnggiantspt @youtubebrasil @99food @casasbahia @domestikabrasil @polishop @naturabroficial @indriver @ifood @agoracorretora @mcdonaldsbr @timbrasil @timbrasil vai lá na onda do @slpnggiantspt qua da nisso ',
#  '@bwatrzs @ubereats @burgerkingbr vou pro concorrente\n\nalô @ifood @mcdonaldsbr rsrsrs',
#  '@lucaasgayer @mcdonaldsbr @burgerkingbr comia fodase',
#  'dormi querendo um mc e acordei querendo mc hummmmm domingou e me patrocina bb @mcdonaldsbr',
#  'olá @mcdonaldsbr o @luansantana tá há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e nenhuma se prontificou que tal abraçar a ideia \n\nluan pelo pantanal',
#  'a @123milhas a @mcdonaldsbr e demais que estão obedecendo ao @slpnggiantspt ainda não perceberam que a maioria do povo brasileiro é de direita e só elas terão à perder ao cederem à esta organização criminosa quando o povo acordar o prejuízo delas será enorme',
#  '@monsterpiaza @pamcosta21 @bolsonarosp @hebertsonsantos @mcdonaldsbr @slpnggiantspt @youtubebrasil é foda ainda que sou caçador de bolsonaristas',
#  '@pauladeaf eita 😧 vamos bater um papo sobre isso por dm',
#  'fãs do travis scott estão roubando cartazes do novo lanche dele no mcdonald’s  via @rap24horasblog',
#  'caralho eu reclamei no @ifood que o pedido do @mcdonaldsbr veio frio com refrigerante sem gás sem ketchup e canudo até aqui tudo bem e sem o maldito molho big mac que eu paguei a mais\no ifood foi lá e estornou o pedido\n\nque sac eficiente',
#  'eu vou twittar todo dia até o @mcdonaldsbr me notar e me dar um estoque de molho caipira nem precisa colocar de volta no restaurante só me da o que sobrou',
#  '@andrefabianop @danzo1989 @mcdonaldsbr nos três',
#  'esse ano está muito esquisito mesmo olha o que encontrei na fila do @mcdonaldsbr aqui em ribeirão preto 🤣🤣🤣🤣🐴🐴👨🏻\u200d🌾👨🏻\u200d🌾 peão come lanche também porra e vai de cavalo buscar 🤣🤣🤣🤣\nsextaimperiodosdv \nquartalobossdv ',
#  'cenas fortes de maus tratos dados pelo @mcdonaldsbr a uma indefesa torta de maçã ',
#  'comprar no @mcdonaldsbr pelo @ifood é pedir pra passar raiva atendimento lixo simplesmente ignoram as suas observações no pedido',
#  '@mcdonaldsbr @slpnggiantspt @youtubebrasil mantendo uma cliente 👍',
#  '@vveronezi1 @mcdonaldsbr prova 😍',
#  '@rosoares100 @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil kkkkkkkkkkkkkkkkkkkkkkkk perde 4 ganha 80 você e sua casa é irrelevante entenda',
#  '@mcdonaldsbr @fepaesleme quando vai ter o travis scott meal',
#  'amei a batata @mcdonaldsbr jogaram um carvão queimado e jogaram o molho só no canto amei super valeu meus 15 reais 😍 ',
#  '@paulovieirareal @burgerkingbr @mcdonaldsbr @catherinenatali vc viu essa campanha',
#  '@sheiseverydoubt @mcdonaldsbr e funciona kkkkkkk',
#  '@mcdonaldsbr tá precisando de uns cupons novos no app',
#  '@gabriel1132ga @pamcosta21 @bolsonarosp @hebertsonsantos @mcdonaldsbr @slpnggiantspt @youtubebrasil nossa demais',
#  'to fome de @mcdonaldsbr 🍔🍟',
#  'nas olimpiadas de 2008  o @mcdonaldsbr  fez lanches de cada lugar que participou das olimpíadas e tinha o lanche de beijing gente que saudade desse lanche tenho vontade até hoje',
#  'terceira vez seguida q eu peço o combo de 2 lanche por 16 do @mcdonaldsbr e vem com isso de cheedar \U0001f90f\U0001f90f\U0001f90f\U0001f90f\U0001f90f e sem cebola',
#  '@mcdonaldsbr chamei la',
#  '@kauamts @mcdonaldsbr mlk marcou e fodase kkkkkkkkkkkkkkkkkkkkkkkkkkkkk',
#  '@itzdeboraxxx @dhsouza6 @mcdonaldsbr consciência pesou né kkk',
#  '@paulovieirareal @burgerkingbr @mcdonaldsbr sensacional isso assim eu eu faço merchan de graça',
#  '@fmonteiro0 @mcdonaldsbr a uma vez comi a de banana deles e não gostei muito não mas se eles quiserem mandar de graça eu aceito lkkkkkkkkkkk',
#  'rt @jeffersonline estou sedento pelo molho do big mac mas acho que esgotou 😫 como faz @mcdonaldsbr ',
#  'fiz um pedido no @mcdonaldsbr pela @uberbrasil valentina queria milkshake de morango\n\npedido chegou sem o milkshake dela\n\nentro em contato recebo um “se vira” com o restaurante\n\nrestaurante não atende telefone\n\nmeo nunca mais uso essas paradas só raiva pqp ',
#  '@mcdonaldsbr como assim não teremos o sanduíche do meu mozao vulgo travis scott aqui no br resolve esse bo aí',
#  'postando aqui tbm por motivos de essa foto tá sensacional 🤤\n@mcdonaldsbr ',
#  '@bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil caralho mas é burro demais eouiqwheiuaheiauehqwea chega dar pena',
#  '@mcdonaldsbr seus funcionários sao um lixos não prestam nem para ler as observações',
#  'do nada eu na @mcdonaldsbr da djalma assim 👀😂 ',
#  '@ubersupport @mcdonaldsbr ferrando com a minha janta\nentrega previsão de 9 min = 25 minutos\nlanches frios e molhados pois metade da coca foi fora fizemos a reclamação na ajuda e nem consigo consultar como ficou / vergonha ',
#  '@sergiosepsep @ifood @mcdonaldsbr por isso que devemos valorizar os comerciantes locais',
#  '@spiessantana oi @mcdonaldsbr    @luansantana tá há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e nenhuma se prontificou que tal abraçar a ideia \n\nluan pelo pantanal',
#  '@mcdonaldsbr @pecesiqueira safados apoiadores de pedofilos',
#  'burger king e mcdonalds de mãos dadas pela perversão da infância\n\n',
#  'af apareceu a propaganda da fernanda paes leme comendo um big mac agora tô com vontade @mcdonaldsbr me patrocina',
#  'rt @slpnggiantspt sabor de vitória da democracia  \nnesse mcdiafeliz o sleeping giants quer saber qual o melhor lanche do @mcdonaldsbr…',
#  'foi eu e luis comer no @mcdonaldsbr',
#  '@aanalivia @mcdonaldsbr ah e o cheddar veio sem cebola hahahahha mc donalds está doido',
#  'dai vc quer comer um sorvetinho na @mcdonaldsbrvai no @ubereatsfaz seu pedido e recebe ele aberto e esparramado pela saco o mais triste é o suporte que eu tiveum simples sentidos mtvamos melhorar e fica por isso msm e a culpa não é do entregador ',
#  '@shandinnnnn ta dropando no @mcdonaldsbr ',
#  '@juquintella @mcdonaldsbr é paixão 😍',
#  '“o amor conquista tudo” diz a nova campanha do @burgerkingbr da finlandia onde o king aparece  beijando ronald @mcdonaldsbr a ação é em apoio a semana do orgulho em helsinque o burguer king tem os melhores e mais ousados publicitários do mundo foda né 👊🏾 ',
#  'mcdonalds só perdeu pra minhas fotos @mcdonaldsbr',
#  'fui no @mcdonaldsbr com o meu irmão e o baguio estava fechado 🤦🏻\u200d♂️🤦🏻\u200d♂️🤦🏻\u200d♂️🤦🏻\u200d♂️',
#  '@gigianoarabc @uberbrasil @slpnggiantspt @youtubebrasil @mcdonaldsbr @gadodecider é gado 🤔',
#  '@mcdonaldsbr @fepaesleme só preciso do endereço do mcdonalds que a @fepaesleme frequenta sem fila e com o molho em frasco disponível porque no mundo real esse molho só se encontra à venda no mercado livre',
#  '@arthuurr @mcdonaldsbr isso não é fome próximo',
#  '@slpnggiantspt @youtubebrasil @99food @casasbahia @domestikabrasil @polishop @naturabroficial @indriver @ifood @agoracorretora @mcdonaldsbr @timbrasil ué acabei d ver anúncio da ifood num vídeo do olavo🤔🤔\nmarketing 2 por 1 aparece aqui e continua aparecendo láentendi pq o nome  dormindo \nburros para caramba  mano rindo mto dos🤡',
#  '@mcdonaldsbr @fepaesleme cadê o lanche do travis ',
#  'oi @mcdonaldsbr  o @luansantana está com um projeto para ajudar o pantanal há dois meses o projeto está pronto e a procura de patrocínio/apoio você poderia ajudar mesmo que seja um tweet sobre a causa já faria a diferença \n\no pantanal chama',
#  'quem patrocinar a live do luan santana em prol do pantanal primeiro ganha @mcdonaldsbr @burgerkingbr \n\nluan pelo pantanal',
#  '@rogerts @mcdonaldsbr hahah é bem por ai',
#  '@paulovieirareal @burgerkingbr @mcdonaldsbr muito 🤯',
#  '@123milhas @helemazevedo é tão bom quando vcs divulgam abertamente esses posicionamentos lacradores me ajuda a lembrar de nunca utilizar nada vinculado a suas empresas \njá tenho um ano sem adquirir nada da @mcdonaldsbr  @burgerkingbr @gillettebr \n@samsungbrasil @dell \nos próximos @naturabroficial',
#  '@paulovieirareal @burgerkingbr @mcdonaldsbr ah como eu queria que a @rackareal fizesse um vídeo zuando isso kkkkkkkk',
#  '@70almeida @palmeirasso51 aposto com vc se vier eu deleto meu tt se não vc me paga um @mcdonaldsbr bora',
#  '@mcdonaldsbr pq maringá não participa mais das promoções',
#  '@mvmarizinha eitaaa chama a gente na dm e conta mais sobre o que houve vamos te ajudar por lá',
#  'oi @mcdonaldsbr posso pedir por aqui pra mim e meus primos\neu 2 quarteirão\nniall big mac\nliam 10 chicken nuggets\xa0\nharry chá gelado\nlouis  mcmuffin com linguiça e ovo 2 hashbrowns e um  milkshake de chocolate provavelmente ele vai querer devolver esse último',
#  '@ofellipesenna @mcdonaldsbr sério amo os de frango tbm sdds cbo',
#  '@mcdonaldsbr fui comprar o sorvete veio isso ',
#  '@jupestana eita chama a gente na dm vamos te ajudar por lá',
#  '@ddorileo ué chama a gente na dm e conta um pouco mais sobre isso aí vamos te ajudar',
#  '@felipealvesm @dhsouza6 @mcdonaldsbr deixa de ser falso',
#  '@rludhriq @riquelmesrn @mcdonaldsbr @pecesiqueira ahh vai tomar no cu por fazer piada com assunto de pedofilia',
#  '@ginghinni7 @ifood @paypalbr @americanascom @mercadolivre @mercadopagobr o @mcdonaldsbr também está censurando e prejudicando pessoas e empresas',
#  'só sei de uma coisa nunca mais irei no drivethru do @mcdonaldsbr \n\nera sempre no mínimo 30 minutos de espera entre entrar na fila e sair com o pedido\n\nmotivo da decisão pedi agora pelo delivery  em 20 minutos a comida chegou perfeita e na mão 😃\n\nshow  👏🏻👏🏻👏🏻',
#  '@ferflower @mcdonaldsbr @ubereatsbr é que eu compro muito dai vez ou outra da algum problema  deve ser karma por ainda insistir em comer bicho',
#  'rt @moisescarlos @slpnggiantspt @youtubebrasil @99food @casasbahia @domestikabrasil @polishop @naturabroficial @indriver @ifood @agoraco…',
#  '@mguifarias @danzo1989 @mcdonaldsbr e o médico disse se alimente bem',
#  'o @mcdonaldsbr aqui na minha cidade tem uma diferença de preço nas mesmas promoções se vc comprar no drive ou pedir pelo @ifood  e ainda acrescenta a taxa de entrega  comprando dois lanches no deivevcpaga 16 ou 18  pelo ifood é 2490  taxa de entrega brasil de merda',
#  '@marcelofideles @mercadopagobr @arthurweint @mcdonaldsbr @slpnggiantspt @youtubebrasil baseado nesse teu pensamento tú é contra o inquérito das fake news',
#  '@slpnggiantspt @youtubebrasil @99food @casasbahia @domestikabrasil @polishop @naturabroficial @indriver @ifood @agoracorretora @mcdonaldsbr @timbrasil eu sou sleepinggiantsbrasil',
#  '@mcdonaldsbr  queria ajuda pra realizar um lanche da tarde com as crianças de uma comunidade próxima da onde eu moro me ajudem aí \n@marilianery  @ericfaria74 @canalzico10 @ricaperrone @opilhado @felipemelo @rcaio03 @gersonsantos08 @giorgiandea @ribasdiego10',
#  '@allyshzz @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil @softxlmj 😏 q isca está lançada',
#  '@ifood e @mcdonaldsbr vocês dois juntos são o patati e o patatá méqui com serviço péssimo e ifood com um suporte que também é a mesma porcaria',
#  '@andreynry @mcdonaldsbr alguns tempos atrás o uber eats não entregava lá em casa irmão',
#  'uma fucking hora no drive do @mcdonaldsbr da taquara rj e ainda nem fazer o pedido consegui parabéns atendimento nota 1000',
#  'im at @mcdonaldsbr in são paulo sp ',
#  '@anderslade @claunutri4 @ograndepensado2 @josefer70649021 @mcdonaldsbr @fepaesleme igadood\nmelhor que o ifood',
#  'rt @ciancaglini15 @domdasthreads @mcdonaldsbr boa dom genial\nalô @casasbahia  parem de me enviar sms agora quero vocês longe de mim…',
#  '@yosoytheoo @mcdonaldsbr tá certo né nunca me leva nessas aí',
#  'isso na concepção do @mcdonaldsbr é um milk shake de chocolate mais branco que jaleco de vet no primeiro ano de graduação decepcionada  ',
#  'já são poucas as opções de lanche vegetariano e agora não acho o bendito no @mcdonaldsbr nem no @burgerkingbr 😭😭😭 só decepção',
#  '@mcdonaldsbr volta o molho caipira pf 😩',
#  '@danzo1989 @mcdonaldsbr eu amooooo mcchiken',
#  '@reldnem18 @sdbrrs @mcdonaldsbr a boa é aproveitar os 25 off no combo do dia que tal matar a saudade do méqui no conforto de casa se liga  😍 ',
#  'é uma putaria só\nninguém se salva hein @burgerkingbr e @mcdonaldsbr\n\n',
#  '@tiostalinurss @josefer70649021 @mcdonaldsbr @fepaesleme os níveis de interpretação de texto tbm',
#  'rt @pormeiodesta amo muito tudo isso ',
#  '@zzviniciusz 👀 esse aí até eu\nalô @mcdonaldsbr',
#  '@romarioferras @mcdonaldsbr pois você só gastou dinheiro',
#  'rt @luanetebaiana oii @mcdonaldsbr bom diia  @luansantana está com um projeto para ajudar o pantanal há dois meses o projeto está pron…',
#  'uma hora se passa e o motoboy no mesmo endereço e nada do nosso lancho chegar entrei em contato com o @ifood que demora uma vida pra responder e também com o @mcdonaldsbr da timoteo o pessoal do méqui foi jóia como de costume ',
#  '@felipealvesm @dhsouza6 @mcdonaldsbr vc n vem só quer saber da minha amg',
#  'rt @exaustaols olá @mcdonaldsbr o @luansantana tá há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e nenhum…',
#  '@arthuurr @mcdonaldsbr agradeça deus quer que vc tenha alimentação saudável rs',
#  'se existe mesmo essa competição entre @burgerkingbr e @mcdonaldsbr o bk deu um soco no estômago com a criação do sundae de halls preto pqp que coisa maravilhosa  sério nunca provei nada igual ',
#  'rt @mlqaln @miguelzinfx @burgerkingbr @mcdonaldsbr tem provas  kkkk',
#  '@lauracdecastro @mcdonaldsbr é um quarteirão ',
#  'aí @mcdonaldsbr come to brazil essa colab do travis scott ',
#  '@joramos @riquelmesrn @mcdonaldsbr @pecesiqueira ah vai você porra vai ditar regra na puta que te pariu eu falo o que eu quiser nesta merda vivo num país livre vai se fuder porra',
#  'por que o @mcdonaldsbr não faz uma campanha nacional mostrando que quer censurar os conservadores a pedido do @slpnggiantspt mostre para o brasil todo o que estão fazendo ou só fazem aqui no twitter',
#  'alo @mcdonaldsbr pq não temos lanche com ovo  ',
#  '@eagorafranco @mcdonaldsbr @rappibrasil poxa @mcdonaldsbr eu te amava tanto',
#  '@mcdonaldsbr \n\nalguém já viu hambúrguer sem hambúrguer ',
#  '@arthurnardaci @sergioorlz @paulovieirareal @burgerkingbr @mcdonaldsbr eh mas eu sou velha e não podia perder a piada  tipo a do pavê rsrsrrsrs',
#  '@podeisso4 @mcdonaldsbr @uberbrasil  2 na aba início/atendimento selecione a opção nova reclamação\n3 preencha os campos relacionados à reclamação\n4 no campo pedido selecione a opção fiscalização \n5 inclua os comprovantes relacionados ao problema',
#  '@paulovieirareal @burgerkingbr @mcdonaldsbr o mkt do bk é sensacional mas as lojas aqui em sp são um lixo tem dia que não tem coca no outro dia não tem gás no outro não tem carne \nisso mesmo um loja aqui em sp colocou um cartaz dizendo que estavam sem carne então invistam mais em qualidade do que em mkt',
#  '@lmjscruel @kccutes @mcdonaldsbr me fala em qual foi pra eu nunca correr esse risco pelo amor de deus',
#  '@dianesouza7 eita 😶 dá mais detalhes pra gente do que rolou por dm',
#  'eu só queria comer o hambúrguer do travis 😩 @mcdonaldsbr',
#  '@fabiocatena @mcdonaldsbr @uberbrasil comigo os entregadores do @ifood gostam de sumir com a comida outra vez até pediram nosso número pra conversar como se tivessem sequestrado nossa comida mandei tomar no cú mas consegui resolver com o restaurante são tudo umas bostas esses serviços',
#  '@brucbass @mcdonaldsbr nossa sim 😭',
#  '@alvesmaiira @mcdonaldsbr preciso talvez amanhã',
#  '@nindjacondor13 @mcdonaldsbr @uberbrasil mas eh claro que mandaram né rs ',
#  '@juliebarber01 @arthurnardaci @paulovieirareal @burgerkingbr @mcdonaldsbr perco a razão mas não perco a piada 😔✌🏽',
#  'rt @erdgad e ae @mcdonaldsbr já pode chamar a recayd pra estrelar a campanha de vcs no br minha dm tá aberta abs',
#  '@josenalencar @ifood uma vez pedi um @mcdonaldsbr pelo @ifood com uma batata extra que não recebi ao reclamar ganhei um “bônus” no valor para futuras compras até aí beleza o problema é que o “bônus” expirou em uma semana perdi nunca mais',
#  '@nataliapael @mcdonaldsbr @ifood aaaii então eu sempre quis pedir do chiquinho mas a taxa me quebra 😫 a taxa do mcdonalds tava 6 reais e veio assim',
#  '@mcdonaldsbr chamei ja temos histórico de dm',
#  '@anamnesias @mcdonaldsbr kkkkkk um dia vocês me darão mais crédito',
#  'bem que podia ter um @mcdonaldsbr em canela 🥺',
#  'rt @oproprionando @oiiuiz @mcdonaldsbr problematizaram a forma como um nugget veste pijamas\n\nparabéns esquerda vc conseguiu',
#  'eu apenas queria comer um @mcdonaldsbr pra fechar meu domingo em paz até aí tudo bem\ncomo faz com a preguicinha de domingo pede um mcdonalds da loja hilário gouveia em copacabana @rappibrasil \n\nacompanhem aí que experiência magnífica pra n dizer o contrário 👇🏻',
#  'travis scott adiciona 37 novos itens para venda em sua colaboração com o mcdonald’s  via @rap24horasblog',
#  '@mcdonaldsbr os senhores poderiam por favor trazer o lanche collab com o travis scott pro brasil\n\neu só queria um bonequinho do travis scott\nobrigado 🙏🙏🙏',
#  '@paypal @ifood @dellnobrasil @mcdonaldsbr @uberbrasil @paypalbr @hotmart @slpnggiantspt \n\nacima vemos empresas que apoiam censura e perseguição ideológica contra conservadores\n\npessoas corretas e justas deveriam deixar de ser clientes ou fornecedores dessas empresas',
#  '@danylawyer1 @gilsonevangel12 @preciosadopapai @mcdonaldsbr @slpnggiantspt @youtubebrasil @subwaybrasil @burgerking não lixo mau caráter da sua laia vou bloquear mesmo',
#  '@anittaoffense @mcdonaldsbr desculpa eu ainda não tenho namorado',
#  '@mcdonaldsbr @pecesiqueira que coisa hein @mcdonaldsbr agora vcs estão apoiando pedófilos 🤮',
#  'rapidão \n@burguerking1 ou @mcdonaldsbr  pra agora \n\n🍔🍔',
#  '@sassahb @burgerkingbr @mcdonaldsbr né isto mana eu amei de mais 😍',
#  '@vivicanassa @mcdonaldsbr então vá kkkk',
#  'o mcdonalds aqui no br ta vendendo o travis scott burger ou não',
#  '@mcdonaldsbr oh mano seis não responderam mais nada eu to com fome de queijo',
#  'olha nem o cbo de volta no cardápio do @mcdonaldsbr  é capaz de me fazer sorrir mais',
#  '@cullensrta @mcdonaldsbr amiga quando eu crescer quero ser igual a você',
#  '@faxinaboa @kibonbr vcs já observaram o big mac a finura dos hambúrgueres @mcdonaldsbr  parece papel é surreal e eles acham que nós não observamos q passa batido ou seja que somos trouxas n compro agora faço em ksa fica delicioso',
#  'oi @mcdonaldsbr  o @luansantana tá há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e nenhuma se prontificou que tal abraçar a ideia \n\nluan pelo pantanal',
#  '@alexferre1ra @burgerkingbr @mcdonaldsbr quero ser o padrinho 🤣❤',
#  'rt @albertosuzano @slpnggiantspt @youtubebrasil @99food @casasbahia @domestikabrasil @polishop @naturabroficial @indriver @ifood @agorac…',
#  '@bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil hahahahahahaa vai tomar no cu seu doente @bolsonarosp',
#  'hoje é dia do gordo mesmo @mcdonaldsbr manda um presente pra mim',
#  'vagas de emprego abertas no mcdonalds  fevereiro 2020  ',
#  '@clubedopairico @mcdonaldsbr fora era sair levemente embriagado do role estar no uber e pedir pra passar no mc donalds e q corrida q era 1020 ficar 90 hahahahahha',
#  'almofada de nuggets do travis scott x mcdonald’s é vendida por quase 500 reais  via @rap24horasblog',
#  '@mcdonaldsbr me patrocina bjs',
#  'comprei um @mcdonaldsbr pedi sem salada veio com salada pedi para viagem veio sem embalagem e faltando guardanapos',
#  'rt @mauroalveszl vendo empresas patrocinando censura @ifood @timbrasil @mcdonaldsbr juntos com criminosos do @slpnggiantspt \nboicotemc…',
#  'rt @slpnggiantspt oii @mcdonaldsbr tudo bem por aqui temos fome de verdade infelizmente encontramos seu anúncio em um canal no @yout…',
#  'sinto muito mas ou parem com essa palhaçada ou saio e não ajudo mais nas campanhas\nvcs estão ridículos\n@mcdonaldsbr e @burgerkingbr \nchega ',
#  'se apaixonei pelo garoto do @mcdonaldsbr 😍',
#  '@mvmarizinha beleza seguimos por lá',
#  '@isaahduarte nossa que chato esse não é o nosso padrão chama a gente na dm que podemos te ajudar',
#  'rt @dedicoatilr olá @mcdonaldsbr o @luansantana está há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e ne…',
#  'égua @burgerkingbr vcs estão vacilando aqui no no bk do shopping metrópole em ananindeua quase todo dia o refri tá quente e falta gelo vou ter que mudar pro @mcdonaldsbr',
#  '@nemiasmelloo @jpsantana09 @mcdonaldsbr mas suave a gente vê essa meta aí kkk',
#  '@mcdonaldsbr algo pra dizer a respeito eu shippo😍 @burguerkingbr ',
#  '@mirodriguess @mcdonaldsbr vim curtir pq pediu no whatsapp kkkkkkkkkkkkkkkkkkkk',
#  'pedi um lanche com duplo hambúrguer no @mcdonaldsbr e adivinha veio só o queijo 😍😍😍 ',
#  '@fabiocatena @mcdonaldsbr @uberbrasil @ifood @ubereatsbr e cabe processo sim o ideal é você ir no procon e acionar as duas empresas quanto na s provas que você tiver melhor se não for solucionado pelo procon aí entra com processo nas pequenas causas e ainda exige reparação de danos',
#  'obrigada aos envolvidos matei quem tava me matando @mcdonaldsbr 🍔🍟❤ ',
#  '@rodrigoedgard @siganelsonmotta @slpnggiantspt @mcdonaldsbr @youtubebrasil os nossos pracinhas são fascistas seu m',
#  '@mneto1433 @mcdonaldsbr para não me julga hahahah primeiro você prova',
#  'agora o @burgerkingbr manda sache e guardanapo ja o @mcdonaldsbr custa a mandar o lanche porem ambos tem algo em comum\n\no sanduiche que vem gelado',
#  '@mcdonaldsbr primeiro vc mudou o queijo quente e agora tirou o pão com ovo e bacon do cardápio pq🥺',
#  'rt @domdasthreads @ailtonbenedito @ludmilagrilo @mcdonaldsbr dr isso ficou evidenciado a partir do momento em que acataram a  acusação f…',
#  '@lsdshabbo @burgerkingbr @mcdonaldsbr queria ein pena que é fake eu acho',
#  'oii @mcdonaldsbr bom diia o @luansantana está com um projeto para ajudar o pantanal há dois meses o projeto está pronto e a procura de patrocínio/apoio você poderia ajudar mesmo que seja um tweet sobre a causa já faria a diferença \n\no pantanal chama',
#  'mcdonalds lança combo em parceria com travis scott\n',
#  'minha lembrança de hoje no insta é um lanche do @mcdonaldsbr  será um sinal',
#  '👀 “o amor conquista tudo” diz a nova campanha do @burgerkingbr da finlandia onde o king aparece  beijando ronald @mcdonaldsbr a ação é em apoio a semana do orgulho em helsinque o burguer king tem os melhores e mais ousados publicitários do mundo ',
#  '@devezze acho que o @mcdonaldsbr tem que mandar 🥺',
#  '@andrefabianop @mcdonaldsbr to chocado ☹\n@mcdonaldsbr resolva isso',
#  '@xshamilx @josefickk @mcdonaldsbr kkkkkkkkkkkkkkk vou ser obrigada a concordar',
#  'vai ter merchan do @matue30 com o @mcdonaldsbr  \ncom boneco do tuê',
#  '@dupaschoal @mcdonaldsbr @burgerkingbr não mesmo \neles querem é saber de grana',
#  'podia lançar uns bonequin do @matue30 ne @mcdonaldsbr',
#  'oii @mcdonaldsbr bom dia o cantor @luansantana está com um projeto para ajudar o pantanal há dois meses o projeto está pronto e a procura de patrocínio/apoio você poderia ajudar \nmesmo que seja um tweet sobre a causa já faria a diferença',
#  'obrigado @mcdonaldsbr por me alegrar na bad do fim do domingo ',
#  'e essa é a resposta do @mcdonaldsbr  vendem uma coisa e entregam outra ',
#  '@thatabernard @vivicanassa @mcdonaldsbr você é uma draga amiga hahahahahahahahahahah',
#  'a noite vou pedi @mcdonaldsbr',
#  'finalmente o @mcdonaldsbr daqui de friburgo reformou benza a deus',
#  '@fabiocatena @mcdonaldsbr @uberbrasil putz aí é foda',
#  '@boredricboy @mcdonaldsbr 🤣🤣🤣🤣\n\nvelhos hábitos nunca mudam  😅',
#  '@carolinenevesgo @mcdonaldsbr sério hahahaha vem pro rj ❤️',
#  '@paulovieirareal @burgerkingbr @mcdonaldsbr ousado seria se ele estivesse\ndescabelando o palhaço 😬\ndurante o beijo bem coisa de cinema',
#  'mó esculacho n ter esse travis scott meal nos mcdonalds br',
#  'oi @mcdonaldsbr hoje meu coração foi partido em mil pedaços ao descobrir que não tem mais o mc veggie era meu favorito veggie de fast food 🥺 vamo agiliza o processo pra trazer meu lanchinho de volta os vegetarianos agradecem bjs',
#  'rt @clubedopairico só sei de uma coisa nunca mais irei no drivethru do @mcdonaldsbr \n\nera sempre no mínimo 30 minutos de espera e…',
#  '@mcdonaldsbr tóxico tirou o único lanche vegetariano do cardápio \n am i a joke to you',
#  'por que @mcdonaldsbr  por que não lançam o burgão do travis aqui no br',
#  'rt @vivimonteir8 deixem de comprar no @mcdonaldsbr @mcdonalds eles apoiam a censura ',
#  '@opredao @mcdonaldsbr dps que perder vai ficar chorando',
#  'oii @mcdonaldsbr  bom diia  @luansantana está com um projeto para ajudar o pantanal há dois meses o projeto está pronto e a procura de patrocínio/apoio você poderia ajudar mesmo que seja um tweet sobre a causa já faria a diferença \n\no pantanal chama',
#  'não entendo qual a dificuldade que o @burgerkingbr e o @mcdonaldsbr tem em enviar os pedidos certos pelos app de entrega eu sempre tenho problema com eles é impressionante',
#  '@nemiasmelloo @jpsantana09 @mcdonaldsbr to falando kkkkkkkkkkkkk',
#  '@alvesmaiira @mcdonaldsbr sou tão caipira aqui que se eu quiser comer mcdonalds tenho que ir para a cidade vizinha 😂',
#  'alo @mcdonaldsbr quando que vocês vão começar a entregar em vargem pequena \n\nassim n daaaaa',
#  '@andysilvaa @burgerkingbr @mcdonaldsbr nenhum',
#  'a vcs empresas q dão voz à agenda da esquerda progressista revolucionária comunista globalista e ainda tem ligação com o sleeping giants não pensem q campanhas de boicote não funcionam\na @netflix e a @mcdonaldsbr sentiram na carne no caso desta última literalmente ',
#  'comi um mclanche feliz e até agora eu tô triste\n\n@mcdonaldsbr você me prometeu 😔',
#  '@bebgs @mcdonaldsbr pediu pelo uber eats  eu pedi esses dias e veio com as batatas ensopadas de refri pedi a ajuda no suporte e recebi os 60 de volta no cartão',
#  '@filiperavoque foi mal que isso tenha rolado 😕 chama a gente na dm',
# ...
#  '@mcdonaldsbr comprei ontem à noite 4 quarteirões pelo @ubereats e vieram frios e borrachudos como se estivessem prontos faz tempo lá\npéssimo negócio',
#  'poxa @mcdonaldsbr  cadê o picles dos meus lanches nem o meu quarteirão e nem o meu big mac vieram com picles \n\n@uberbrasil ',
#  'atualiza as promoções no aplicativo @mcdonaldsbr',
#  'podia ter um méqui em ilhéus 😔 @mcdonaldsbr',
#  'rt @querosovcluan oii @mcdonaldsbr bom diia o @luansantana está com um projeto para ajudar o pantanal há dois meses o projeto está pron…',
#  '@mcdonaldsbr @fepaesleme legal essa propaganda sem pandemia e sem máscaras \nconvidando pra matar a saudade \nprecipitado não',
#  '@mcdonaldsbr acabo de sair da unidade do mc da intendente e estava sendo cobrada a  pelos combos e o preço estava outro na tela isso foi no drivena hora de pagar reclamei e reviram o preço \nainda disseram que os cupons do aplicativo não valem\neles fazem a promoção deles',
#  'rt @hbwhorann @zeppelinfour mds siim eu com certeza assino e apoio o milkshake larry aaaaaa\n\n@mcdonaldsbr vc tá perdendo money podia…',
#  '@tomfm @mcdonaldsbr oh eu não vou patrocinar quem propaga ódio\n\nvai tomando aí\n😅',
#  '@jornalveracruz @eusoumbc se continuar assim logo não poderei mais comer um hambúrguer em lugar nenhum pois bem @mcdonaldsbr e @burgerkingbr black list pros dois de agora em diante só @bobsbrasil ou @giraffasoficial',
#  '@vveronezi1 @mcdonaldsbr os dois juntos pega a batata salgadinha e chucha no sorvete 😍😍😍😍😍😍',
#  'fui rejeitada no processo de estágio de novo me dá um duplo cheddar pra afogar as mágoas @mcdonaldsbr ',
#  '@clubedopairico @mcdonaldsbr devia ter dito por que não como mais md',
#  '@fabiocatena @mcdonaldsbr @uberbrasil catena vc pagou e nao rolou o reembolso entao entra com ação nas pequenas causas obrigação de fazer ou coisa certa chama no privado ai',
#  'eu que tô morrendo de comer um @mcdonaldsbr sério ',
#  'to viciado no molho especial do @mcdonaldsbr pena que edição limitada 😭😭😭😭😭',
#  'oi @mcdonaldsbr não como mc desde março e quando eu finalmente vou pedir meu combo fico sabendo que o chá saiu do cardápio por que',
#  '@slpnggiantspt @youtubebrasil @99food @casasbahia @domestikabrasil @polishop @naturabroficial @indriver @ifood @agoracorretora @mcdonaldsbr @timbrasil quanto mais vcs trabalham mais soldados recrutamos\n',
#  '@vitorialaris @mcdonaldsbr meu sonho',
#  'fui no @mcdonaldsbr querendo um club house e informaram que saiu do cardápio como assim chateada era o melhor lanche',
#  '@rosoares100 @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil vc é mt retardada vei kkkkkkkkkk',
#  'terceira vez que meu pedido vem errado já posso pedir música no fantástico @mcdonaldsbr',
#  '@zeppelinfour @mcdonaldsbr siim mdsss pfvr @mcdonaldsbr eu imploro',
#  '@karolinda98 @mcdonaldsbr kkkkkkkkkkk nem te conheço menina esquisita',
#  '@waltzlilica eitaaa 😳 não era pra ser assim chama a gente na dm',
#  '@jairbolsonaro @mdregionalbr @govbr atenção vamos boicotar as seguintes empresas que caíram na lábia do grupo de extrema esquerda sleeping giants\ncasas bahia\npolishop\nmcdonalds\nifood\nnatura\npaypal\nágorainvestimentos\ndomestikabrasil\nhotmart\nbayerbrasil\ndellbrasil\nbudweiser\nuberbrasil',
#  'tava animadona que a janta hoje seria @mcdonaldsbr e o pedido veio todo errado foi triste 😔',
#  'nunca imaginei passar uma raiva tão grande com o @mcdonaldsbr \n100 reais em pedido p n vir nem a metade sinceramente',
#  '@jonitd @mcdonaldsbr caralho q tristeza',
#  'eu não acredito que eu vi o filho do bolsobosta chamando o @mcdonaldsbr de radical de esquerda ',
#  '@delizyo @mcdonaldsbr opa obrigada🙏🏻',
#  'comi @mcdonaldsbr  hoje depois de um fucking ano\n\npeguei o club house de frango pq sim amo lanche de frango e foi uma surpresa boa demais nível hamburgueria sem zoar',
#  '@mcdonaldsbr lancem o combo do travis scott aqui por favor',
#  'nhami nhami at @mcdonaldsbr in são luís ma ',
#  '@mcdonaldsbr pois é nem pude aproveitar o lanche',
#  '@alvesmaiira @mcdonaldsbr é muito bom eu não fui ainda',
#  '@fabiocatena @mcdonaldsbr @uberbrasil uber eats é foda tive problema com uma pizza que veio toda dobrada pra um lado só da caixa liguei no restaurante e eles disseram pra pedir pelo ifood pq eles tem controle dos entregadores já no uber não agora sobre item faltando consegui reembolso uma vez só',
#  '@qhelldocontra @mcdonaldsbr bom saber testarei',
#  '@slpnggiantspt @mcdonaldsbr @youtubebrasil perseguição seletiva\nnão pediram boicote ao o globo que pratica fake news diariamente\n\n',
#  'início de um sonho / deu tudo certo\n@mcdonaldsbr me patrocina por favor e me manda uns lanches 🥺  ',
#  '@slpnggiantspt @mcdonaldsbr @youtubebrasil mcdonalds nunca mais\n ',
#  '@mcdonaldsbr eu não estou acreditando até agora que o meu lanche favorito vulgo mc picanha saiu de linha ',
#  '@luizgnribeiro @mcdonaldsbr taí um ngc que n compro mais por app é sorvete do mc outra vez a gt pediu um sundae que chegou só o suco pqp',
#  'fiz uma torrada com ovo frito e senti gosto de um @mcdonaldsbr  kkkkkkk',
#  '@mcdonaldsbr pode voltar o molho caipira agora não arrasa comigo quem quiser molho do big mac que passe a batata dentro do lanche volta o caipira agora',
#  '@mcdonaldsbr como que eu vou continuar vivendo sem tomar suco de maracujá duas vezes que venho e não tem aí descobri hoje que saiu do cardápio me senti apunhalada pelas costas 🥺',
#  '@marcelo30757598 @bateria12v @bolsonarosp @backtothewar @mcdonaldsbr @slpnggiantspt @youtubebrasil eu só falei vdds',
#  'o mcdonald’s e a aberje associação brasileira de comunicação empresarial anunciam a abertura das inscrições para a segunda edição do programa escalando o futuro que vão do dia 15/09 até 08/10\nsaiba mais no site  ',
#  '@bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil mc donalds comunista não sabia não o vermelho vem de onde caraca vc é muito inteligente deputado exemplo a ser seguido viu',
#  'rt @thesupersantana olá @mcdonaldsbr o @luansantana está há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal…',
#  '@anderslade @claunutri4 @ograndepensado2 @josefer70649021 @mcdonaldsbr @fepaesleme eu conheço alguns preciso alimentálos',
#  'segunda vez que compro torta de maçã no @mcdonaldsbr é encontro cabelo ',
#  'rt @rap24horasblog nle choppa diz para pessoas não comerem lanche do mcdonald’s do travis scott e sim comida orgânica ',
#  '@leide76367084 @observint @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil meia dúzia de gato pingado não faz mal nem para o seu zé dono de bar',
#  'rt @univ3rsosantana oi @mcdonaldsbr o @luansantana tá há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e ne…',
#  '@mgzin @packersbr @mcdonaldsbr @uberbrasil @ubereatsbr deletei o eats e parei de usar o uber depois do que fizeram',
#  'mais um dia comprando @mcdonaldsbr e pagando por extra que não veio parece até golpe',
#  '@giovanameloc @mcdonaldsbr sem convidar',
#  '@mcdonaldsbr @fepaesleme ae mequí se tu comentar aqui eu compro mequí durante uma semana e usa a tag \n\nlaurenwithjohnny\n',
#  '@romulomasson @mcdonaldsbr nossa eu amo e notei que todos os restaurantes estão esgotados 😥',
#  '@alvesmaiira @vivicanassa @mcdonaldsbr mas não gosto de fast  food  no máximo subway  pelo menos cozinho super bem quando eu for te ver vamos engordar horrores',
#  '@bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk até o mc donalds virou da esquerda agora o bananinha mesmo define que os conservadores são quem estao espalhando fake news carai bananinha vc não da uma bola dentro parça ',
#  'aqui está o verdadeiro homem que merecia uma collab com o @mcdonaldsbr tal qual travis scott ',
#  '@dupaschoal poxa a gente sente muito que isso tenha rolado 😕 vamos conversar por dm',
#  'rt @gustavo44747754 vale a pena lembrar que aniversariante do dia já pagou a dívida no domingo pagou em grande estilo após 2 anos\n\na ap…',
#  '@gtzinn14 @mcdonaldsbr tao dando mole dms',
#  'rt @umaestrelals oi @mcdonaldsbr o @luansantana tá há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e nenhu…',
#  'desesperada indo em tds os @mcdonaldsbr atrás do molho de big mac pelo amor de deus todos acabaram',
#  'rt @oiiuiz é essa turma aqui que vc tá tentando agradar quando cede ao sleeping giants @mcdonaldsbr\n\nboa sorte😂 ',
#  '@diiegott @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil se o mc donalds é contra algum bolsonaroeu vou começar a almoçar big mac e cheddar  todo dia 😍',
#  '@mcdonaldsbr  \neu que lute dps na academia ',
#  '@pedropinaud @mcdonaldsbr vai que dá certo ',
#  'meu deus pq a batata do @mcdonaldsbr é tao boa devia ter um refil de batata também so acho viu 👁👄👁',
#  'rt @baladiprata e essa política do @mcdonaldsbr tubarão cobrar mais caro no @ifood que na loja e ainda cobrar o frete sacanagem eim…',
#  '@cavorro comi com muito nojo pra sentir uma saudade da porra depois ô @mcdonaldsbr ajuda',
#  'rt @fabiocatena fiz um pedido no @mcdonaldsbr pela @uberbrasil valentina queria milkshake de morango\n\npedido chegou sem o milkshake dela…',
#  '@fairlybitch @mcdonaldsbr to mt puto',
#  '@guibortoli94 @ifood @mcdonaldsbr vou fazer o mesmo',
#  '@misscopa @claulanz @mcdonaldsbr gente ela até era bonitinha né',
#  'aieeeeee brasellll quero chegar logo em casa pra assistir toronto e boston pq já perdi a quebrada do denver forçando o jogo 6 fiz um pit stop no @mcdonaldsbr ahahahanbanaespn',
#  'que refrigerante ruim hein @mcdonaldsbr 🤢🤮',
#  'rt @fclsdomeulado oi @mcdonaldsbr o @luansantana tá há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e nen…',
#  'saudade dele do cbo e aí @mcdonaldsbr vamo fortalecer a firma e colocar de volta no cardápio',
#  '@spiessantana @liviamarmols oi @mcdonaldsbr  o @luansantana tá há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e nenhuma se prontificou que tal abraçar a ideia \n\nluan pelo pantanal',
#  '@mcdonaldsbr eu preciso muito de um agora',
#  '@boldtarthur @mcdonaldsbr aii sim',
#  'aee @mcdonaldsbr tive um atendimento bem ruinzinho \nbatata frita fria \nsanduíche tbm frio \ne refrigerante sem gás \n\ndias de luta dias de glória \nhoje foi de luta',
#  '@stevemaida lembrando que se for rolar mesmo precisamos mandar um caminhão de @mcdonaldsbr para o @coldzera \n\nsem cold gordo = sem major',
#  '@brendhathayssa @mcdonaldsbr cadeeeeeeee eu quero',
#  'pra variar o combo @ifood  @mcdonaldsbr deu problema parece que eles competem para ver quem consegue causar mais dor de cabeça no cliente coragem',
#  '@lactabis po @mcdonaldsbr volta a fazer um mc flurry com mini bis pf',
#  'vamos ajudar o pantanal  assine a petição  via @changebr',
#  '@mcdonaldsbr agora só falta fazer o mesmo c o cheddar',
#  '@stfngm @mcdonaldsbr então já vou deixar a boa aqui vamos de mcoferta  mcflurry com uma oferta exclusiva só pra você  ❤️ ',
#  'amo muito tudo isso ',
#  'travis scott chama fã batalhando contra câncer comendo seu lanche do mcdonald’s de seu “herói”  via @rap24horasblog',
#  '@devezze @mcdonaldsbr kkkkkkkkkk cavalo dado não se olha os dentes',
#  'pra melhorar ainda o @mcdonaldsbr fez o entregador da @rappibrasil esperar por mais de uma hr no estabelecimento fazendo o cara perder bastante tempo do trabalho dele que depende do número de entregas que ele faz 👇🏻👇🏻 ',
#  '@flaviogordon @mcdonaldsbr @slpnggiantspt @youtubebrasil mcdonalds se associa ao ódio\nboicotemcdonalds \n',
#  'está na ora de @opropriolavo meter varios processos para cima do @slpnggiantspt e marcas @timbrasil @ifood @mcdonaldsbr teram que provar o que estão dizendo ',
#  '@obitin @mcdonaldsbr e ele samba na cara do capitalismo novamente',
#  '@mcdonaldsbr @fepaesleme nunca mais boto os pés em suas lojas enquanto vocês censurarem quem não comete “fake news”\n@odecarvalho',
#  'rei do burger king e ronald mcdonald se apaixonam em campanha do orgulho do bk  via @gpublicitario',
#  'trabalho pra isso 🥰 @mcdonaldsbr ',
#  'batata murcha fria e molhada\nrefrigerante quente e sem gás\ntotalmente arrependido em comprar no @mcdonaldsbr',
#  '@moisescarlos @slpnggiantspt @youtubebrasil @99food @casasbahia @domestikabrasil @polishop @naturabroficial @indriver @ifood @agoracorretora @mcdonaldsbr @timbrasil perfil anônimo com posicionamento claro e viés político definido com objetivo de retirar do debate público alguns dos portavozes da maioria silenciosa e através da espiral do silêncio retirar a capacidade de expressão de toda e qualquer voz conservadora',
#  '@cariocadagema @ichiafarelli @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil tá vagabundo',
#  '@fepaesleme estrela campanha do @mcdonaldsbr criada pela @agenciadpzt  ',
#  'feliz por ter feito tortinha do @mcdonaldsbr em casa mas triste pq não esperei esfriar e queimei a língua',
#  'vou levantar uma petição chega de cocacola sem gás @mcdonaldsbr \neu seria mais feliz',
#  'rt @alecrimluanr oi @mcdonaldsbr o @luansantana tá há dois meses procurando marcas pra apoialo em uma live pra ajudar o pantanal e nenhu…',
#  '@jamesdeliverybr kd meu pedido quase 2h esperando o @mcdonaldsbr que fica na minha esquina entregador fala que o restaurante q esta demorando preciso de ajuda e ninguem atende no 0800',
#  '@mcdonaldsbr me patrocina eu viro seu escravo',
#  '@xxproton @rosoares100 @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil amigo se for ser ignorante assim a direita é pra la gtgtgtgt',
#  '@ifood @mcdonaldsbr qual a dificuldade dos restaurantes acertarem o lanche o meu acabou de vir errado de novo',
#  '@mffrann @mcdonaldsbr @ifood fui teimar e querer enfiar lactose no corpo o universo fez só o dedinho da ivy pra mim 🤣🤣🤣🤣🤣🤣🤣🤣🤣',
#  '@marcosmion eu estava limpando e organizando a loja do @mcdonaldsbr em que eu trabalhava antes dela abrir para os clientes',
#  '@911gih tem sim q eu sei @mcdonaldsbr',
#  'rt @bobstalonecuzao @oiiuiz @mcdonaldsbr lembrando que manifestantes do blm já entraram em um mcdonalds e tocaram o terror por lá também…',
#  'dos mesmos criadores de a terra é plana e nazismo de esquerda agora temos @mcdonaldsbr comunista ',
#  'rt @guiadoscuriosos imagina um mcdonald’s desse aqui no brasil ',
#  '@lecacoimbraa @mcdonaldsbr muito bommmmm 🍟🍨',
#  '@jotabarber @jpsantana09 @mcdonaldsbr já vi que não vai vir',
#  '@dhsouza6 @mcdonaldsbr kkkkkkkkkk ce é doido dms sdds af',
#  '@mcdonaldsbr fui comprar um lanche ontem no mcdonalds da estrada do monteiro campo grande rjfui sem mascara não pude entrar pra comprar meu lanche\ndentro da loja haviam mais de 20 clientes sentados comendo sem máscaravcs instalaram escudos invisíveis nas mesas anticovid ',
#  'rt @jpledier @rosoares100 @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil acabou pra vc @mcdonaldsbr \n\na rosana e sua família…',
#  '@botelhaaa poxa foi mal 😕 vamos bater um papo sobre isso por dm',
#  'menos uma consumidora @mcdonaldsbr 🤐😶 ',
#  'rt @felipelourabras alguém tem q parar o sleeping giants\n\nnão neném  eu vou parar esse perfil de ideal semelhante ao do austríaco e…',
#  '@marcelo30757598 @bateria12v @bolsonarosp @backtothewar @mcdonaldsbr @slpnggiantspt @youtubebrasil ata não é melhor vc aceitar que o bolsonaro é um genocida',
#  '@cocacolabr @mcdonaldsbr gosto de cupom de desconto exclusivos tipo com uns 70 de desconto que e oque cabe no meu bolso🤣',
#  '@mcdonaldsbr @ifood ridículo pedi um combo e veio faltando um lanche e a plataforma não me responde extremo descaso',
#  '@agenciadpzt cria campanha para @mcdonaldsbr  ',
#  '@paulovieirareal @burgerkingbr @mcdonaldsbr inclusive essa é icônica ',
#  'eu não sei se to vivendo ou só esperando a collab do @trvisxx e @mcdonalds chegar no @mcdonaldsbr',
#  'aí sextou e tu pede um @mcdonaldsbr  pelo @ubereatsbr  perfeito né\nnãooo além do refrigerante chegar pela metade veio sem gás e quente\nsextou diferente por aqui e agora ',
#  '@flalaragnoia @mcdonaldsbr tiraram ',
#  'rt @delmindiacosta atenção @proconspoficial outro dia comprei um lanche é um refrigerante no @mcdonaldsbr  unidade av brigadeiro lui…',
#  'rt @serafimdoceu mequipatrocina  @mcdonaldsbr poderia patrocinar o hélio como o cachorro propaganda olha essa batata frita cara deu…',
#  '@mcdonaldsbr chamei']

# %%
train_text_raw = ' '.join(train_cleanup)
train_text_raw
# Out:
# 'por isso eu prefiro o @mcdonaldsbr  queria comer uma besteirinha tipo um big tasty do @mcdonaldsbr  🤤 @sergiosepsep @mcdonaldsbr @ifood eu já tive problemas com o pedido do mc mas foi pelo ubereats liguei no ubereats fiz a reclamação e eles estornaram o valor no meu cartão tudo isso em menos de 5 min 🙏🏻 ninguém merece ficar puto com o pedido qdo chega e ainda levar canseira depois disso @mvmarizinha @mcdonaldsbr mentira fui no @mcdonaldsbr do @rapososhopping e fiz meu pedido quando pedi guardanapo a gerente isso mesmo extremamente grossa virou as costas e me deixou falando até nunca mais rt @thia6o0 @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil sim nunca percebeu as mensagens ocultas na logo  rt @rap24horasblog combo do travis scott no mcdonald’s faz enorme sucesso e esgota ingredientes do fast food  via @… @mvmarizinha @mcdonaldsbr sério kkkkkkkkkkkkkkkkkk @mcdonaldsbr @jamesdeliverybr favor voltem com  o refrigerante em lata que saco toda vez vem derramado metade do refrigerante e da ultima vez o refri ainda deu um banho na batata que saco olá @mcdonaldsbr o @luansantana está há procura de empresas pra apoiálo em uma live em prol do pantanal que tal abraçar essa ideia\n\nluan pelo pantanal @jotabarber @jpsantana09 mais conhecido como @mcdonaldsbr a felicidade que um @mcdonaldsbr proporciona hahahahaha novafotodoperfil  @lauras @mcdonaldsbr desejei como me explicar @mcdonaldsbr pode existir molhos big mac picanha e bacon invisível  @mcdonaldsbr @fepaesleme domingo passado  dia 13/09 comprei 3 bicmac e paguei para ter hambúrguer em dobro quando cheguei em casa abri o pacote dos lanches  sem as carnes extras o e nem esse potãofui roubado  na loja da vmatilde  radial lesteminha experiência constrangedora e péssimo lanche @affonsoju @steviveiros @mcdonaldsbr e eu só queria um giga tasty mano @bolsonarosp @mcdonaldsbr @slpnggiantspt @youtubebrasil vai procurar um psiquiatra lunático kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk queria era tá comendo um @mcdonaldsbr @rkteixeira7 @mcdonaldsbr ta achando q tu é o travor escotix seu fdp tá de sacanagem né @mcdonaldsbr   @nowornevergbye @claunutri4 @ograndepensado2 @josefer70649021 @mcdonaldsbr @fepaesleme gado socializado socializando com amigos bonita sua atitude @sennadobone @oestagiariodoei @casimiro @mcdonaldsbr patrocina os cara aí po @baamarcal @mcdonaldsbr @ifood pois é essa embalagem é pra pedido no balcão agora eu penso o tanto de copo que não chegou tombado assim  @mcdonaldsbr vocês cederam a pressão da sleeping giants  ok eu já tinha boicotado o bk é bom que agora só como the fifities vou ficar snob kkkkkkkk @alvesmaiira @mcdonaldsbr eita  assim que eu provar dou minha opinião @oiiuiz @mcdonaldsbr chupa mequi  na frente da loja que tô trabalhando hoje tem um @burgerkingbr e um @mcdonaldsbr e a dúvida de qual ir dps do job só pra tomar um sorvetinho  @fabiocatena @mcdonaldsbr @uberbrasil sentimos em saber que o pedido não chegou como esperava \n oras que bobagem eu esperava mesmo não receber fiquei muito satisfeito parabéns pelo excelente serviço vou até favoritar e dar gorjeta @leozabotto eita vem conversar com a gente na dm queremos te ajudar @mcdonaldsbr de pelotas tô esperando o lanche do travis scott favor lançar pra nós e mais uma feita de trouxa pelo @mcdonaldsbr com papel no lanche última chance que dei p esse estabelecimento que diz ser padronizado segundo o email que recebi único retorno que tive  @1dpsychic @mcdonalds @mcdonaldsbr bora nego fazer um milkshake com o nome do patrão  @rogersouza96 @mcdonaldsbr já tava mordido q veio sem batata do nada brotam aqui com mais😂 acordei com vontade de comer cbo  alo @mcdonaldsbr demorou pra voltar ele definitivo pro cardápio rt @domdasthreads bom dia @mcdonaldsbr tudo bem\nficamos sabendo que vcs apoiam o comunismo aquela ideologia nefasta que torturou e mato… @mcdonaldsbr esse é o padrão agora dos lanches  @zanettils @mcdonaldsbr kkkkkkkkkkkkkkk eu fui buscar uma maionese na cozinha pq ta seco seco seco sem brincadeir ...

# %%
todas_palavras_train = train_text_raw.split()
todas_palavras_train
# Out:
# ['por',
#  'isso',
#  'eu',
#  'prefiro',
#  'o',
#  '@mcdonaldsbr',
#  'queria',
#  'comer',
#  'uma',
#  'besteirinha',
#  'tipo',
#  'um',
#  'big',
#  'tasty',
#  'do',
#  '@mcdonaldsbr',
#  '🤤',
#  '@sergiosepsep',
#  '@mcdonaldsbr',
#  '@ifood',
#  'eu',
#  'já',
#  'tive',
#  'problemas',
#  'com',
#  'o',
#  'pedido',
#  'do',
#  'mc',
#  'mas',
#  'foi',
#  'pelo',
#  'ubereats',
#  'liguei',
#  'no',
#  'ubereats',
#  'fiz',
#  'a',
#  'reclamação',
#  'e',
#  'eles',
#  'estornaram',
#  'o',
#  'valor',
#  'no',
#  'meu',
#  'cartão',
#  'tudo',
#  'isso',
#  'em',
#  'menos',
#  'de',
#  '5',
#  'min',
#  '🙏🏻',
#  'ninguém',
#  'merece',
#  'ficar',
#  'puto',
#  'com',
#  'o',
#  'pedido',
#  'qdo',
#  'chega',
#  'e',
#  'ainda',
#  'levar',
#  'canseira',
#  'depois',
#  'disso',
#  '@mvmarizinha',
#  '@mcdonaldsbr',
#  'mentira',
#  'fui',
#  'no',
#  '@mcdonaldsbr',
#  'do',
#  '@rapososhopping',
#  'e',
#  'fiz',
#  'meu',
#  'pedido',
#  'quando',
#  'pedi',
#  'guardanapo',
#  'a',
#  'gerente',
#  'isso',
#  'mesmo',
#  'extremamente',
#  'grossa',
#  'virou',
#  'as',
#  'costas',
#  'e',
#  'me',
#  'deixou',
#  'falando',
#  'até',
#  'nunca',
#  'mais',
#  'rt',
#  '@thia6o0',
#  '@bolsonarosp',
#  '@mcdonaldsbr',
#  '@slpnggiantspt',
#  '@youtubebrasil',
#  'sim',
#  'nunca',
#  'percebeu',
#  'as',
#  'mensagens',
#  'ocultas',
#  'na',
#  'logo',
#  'rt',
#  '@rap24horasblog',
#  'combo',
#  'do',
#  'travis',
#  'scott',
#  'no',
#  'mcdonald’s',
#  'faz',
#  'enorme',
#  'sucesso',
#  'e',
#  'esgota',
#  'ingredientes',
#  'do',
#  'fast',
#  'food',
#  'via',
#  '@…',
#  '@mvmarizinha',
#  '@mcdonaldsbr',
#  'sério',
#  'kkkkkkkkkkkkkkkkkk',
#  '@mcdonaldsbr',
#  '@jamesdeliverybr',
#  'favor',
#  'voltem',
#  'com',
#  'o',
#  'refrigerante',
#  'em',
#  'lata',
#  'que',
#  'saco',
#  'toda',
#  'vez',
#  'vem',
#  'derramado',
#  'metade',
#  'do',
#  'refrigerante',
#  'e',
#  'da',
#  'ultima',
#  'vez',
#  'o',
#  'refri',
#  'ainda',
#  'deu',
#  'um',
#  'banho',
#  'na',
#  'batata',
#  'que',
#  'saco',
#  'olá',
#  '@mcdonaldsbr',
#  'o',
#  '@luansantana',
#  'está',
#  'há',
#  'procura',
#  'de',
#  'empresas',
#  'pra',
#  'apoiálo',
#  'em',
#  'uma',
#  'live',
#  'em',
#  'prol',
#  'do',
#  'pantanal',
#  'que',
#  'tal',
#  'abraçar',
#  'essa',
#  'ideia',
#  'luan',
#  'pelo',
#  'pantanal',
#  '@jotabarber',
#  '@jpsantana09',
#  'mais',
#  'conhecido',
#  'como',
#  '@mcdonaldsbr',
#  'a',
#  'felicidade',
#  'que',
#  'um',
#  '@mcdonaldsbr',
#  'proporciona',
#  'hahahahaha',
#  'novafotodoperfil',
#  '@lauras',
#  '@mcdonaldsbr',
#  'desejei',
#  'como',
#  'me',
#  'explicar',
#  '@mcdonaldsbr',
#  'pode',
#  'existir',
#  'molhos',
#  'big',
#  'mac',
#  'picanha',
#  'e',
#  'bacon',
#  'invisível',
#  '@mcdonaldsbr',
#  '@fepaesleme',
#  'domingo',
#  'passado',
#  'dia',
#  '13/09',
#  'comprei',
#  '3',
#  'bicmac',
#  'e',
#  'paguei',
#  'para',
#  'ter',
#  'hambúrguer',
#  'em',
#  'dobro',
#  'quando',
#  'cheguei',
#  'em',
#  'casa',
#  'abri',
#  'o',
#  'pacote',
#  'dos',
#  'lanches',
#  'sem',
#  'as',
#  'carnes',
#  'extras',
#  'o',
#  'e',
#  'nem',
#  'esse',
#  'potãofui',
#  'roubado',
#  'na',
#  'loja',
#  'da',
#  'vmatilde',
#  'radial',
#  'lesteminha',
#  'experiência',
#  'constrangedora',
#  'e',
#  'péssimo',
#  'lanche',
#  '@affonsoju',
#  '@steviveiros',
#  '@mcdonaldsbr',
#  'e',
#  'eu',
#  'só',
#  'queria',
#  'um',
#  'giga',
#  'tasty',
#  'mano',
#  '@bolsonarosp',
#  '@mcdonaldsbr',
#  '@slpnggiantspt',
#  '@youtubebrasil',
#  'vai',
#  'procurar',
#  'um',
#  'psiquiatra',
#  'lunático',
#  'kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk',
#  'queria',
#  'era',
#  'tá',
#  'comendo',
#  'um',
#  '@mcdonaldsbr',
#  '@rkteixeira7',
#  '@mcdonaldsbr',
#  'ta',
#  'achando',
#  'q',
#  'tu',
#  'é',
#  'o',
#  'travor',
#  'escotix',
#  'seu',
#  'fdp',
#  'tá',
#  'de',
#  'sacanagem',
#  'né',
#  '@mcdonaldsbr',
#  '@nowornevergbye',
#  '@claunutri4',
#  '@ograndepensado2',
#  '@josefer70649021',
#  '@mcdonaldsbr',
#  '@fepaesleme',
#  'gado',
#  'socializado',
#  'socializando',
#  'com',
#  'amigos',
#  'bonita',
#  'sua',
#  'atitude',
#  '@sennadobone',
#  '@oestagiariodoei',
#  '@casimiro',
#  '@mcdonaldsbr',
#  'patrocina',
#  'os',
#  'cara',
#  'aí',
#  'po',
#  '@baamarcal',
#  '@mcdonaldsbr',
#  '@ifood',
#  'pois',
#  'é',
#  'essa',
#  'embalagem',
#  'é',
#  'pra',
#  'pedido',
#  'no',
#  'balcão',
#  'agora',
#  'eu',
#  'penso',
#  'o',
#  'tanto',
#  'de',
#  'copo',
#  'que',
#  'não',
#  'chegou',
#  'tombado',
#  'assim',
#  '@mcdonaldsbr',
#  'vocês',
#  'cederam',
#  'a',
#  'pressão',
#  'da',
#  'sleeping',
#  'giants',
#  'ok',
#  'eu',
#  'já',
#  'tinha',
#  'boicotado',
#  'o',
#  'bk',
#  'é',
#  'bom',
#  'que',
#  'agora',
#  'só',
#  'como',
#  'the',
#  'fifities',
#  'vou',
#  'ficar',
#  'snob',
#  'kkkkkkkk',
#  '@alvesmaiira',
#  '@mcdonaldsbr',
#  'eita',
#  'assim',
#  'que',
#  'eu',
#  'provar',
#  'dou',
#  'minha',
#  'opinião',
#  '@oiiuiz',
#  '@mcdonaldsbr',
#  'chupa',
#  'mequi',
#  'na',
#  'frente',
#  'da',
#  'loja',
#  'que',
#  'tô',
#  'trabalhando',
#  'hoje',
#  'tem',
#  'um',
#  '@burgerkingbr',
#  'e',
#  'um',
#  '@mcdonaldsbr',
#  'e',
#  'a',
#  'dúvida',
#  'de',
#  'qual',
#  'ir',
#  'dps',
#  'do',
#  'job',
#  'só',
#  'pra',
#  'tomar',
#  'um',
#  'sorvetinho',
#  '@fabiocatena',
#  '@mcdonaldsbr',
#  '@uberbrasil',
#  'sentimos',
#  'em',
#  'saber',
#  'que',
#  'o',
#  'pedido',
#  'não',
#  'chegou',
#  'como',
#  'esperava',
#  'oras',
#  'que',
#  'bobagem',
#  'eu',
#  'esperava',
#  'mesmo',
#  'não',
#  'receber',
#  'fiquei',
#  'muito',
#  'satisfeito',
#  'parabéns',
#  'pelo',
#  'excelente',
#  'serviço',
#  'vou',
#  'até',
#  'favoritar',
#  'e',
#  'dar',
#  'gorjeta',
#  '@leozabotto',
#  'eita',
#  'vem',
#  'conversar',
#  'com',
#  'a',
#  'gente',
#  'na',
#  'dm',
#  'queremos',
#  'te',
#  'ajudar',
#  '@mcdonaldsbr',
#  'de',
#  'pelotas',
#  'tô',
#  'esperando',
#  'o',
#  'lanche',
#  'do',
#  'travis',
#  'scott',
#  'favor',
#  'lançar',
#  'pra',
#  'nós',
#  'e',
#  'mais',
#  'uma',
#  'feita',
#  'de',
#  'trouxa',
#  'pelo',
#  '@mcdonaldsbr',
#  'com',
#  'papel',
#  'no',
#  'lanche',
#  'última',
#  'chance',
#  'que',
#  'dei',
#  'p',
#  'esse',
#  'estabelecimento',
#  'que',
#  'diz',
#  'ser',
#  'padronizado',
#  'segundo',
#  'o',
#  'email',
#  'que',
#  'recebi',
#  'único',
#  'retorno',
#  'que',
#  'tive',
#  '@1dpsychic',
#  '@mcdonalds',
#  '@mcdonaldsbr',
#  'bora',
#  'nego',
#  'fazer',
#  'um',
#  'milkshake',
#  'com',
#  'o',
#  'nome',
#  'do',
#  'patrão',
#  '@rogersouza96',
#  '@mcdonaldsbr',
#  'já',
#  'tava',
#  'mordido',
#  'q',
#  'veio',
#  'sem',
#  'batata',
#  'do',
#  'nada',
#  'brotam',
#  'aqui',
#  'com',
#  'mais😂',
#  'acordei',
#  'com',
#  'vontade',
#  'de',
#  'comer',
#  'cbo',
#  'alo',
#  '@mcdonaldsbr',
#  'demorou',
#  'pra',
#  'voltar',
#  'ele',
#  'definitivo',
#  'pro',
#  'cardápio',
#  'rt',
#  '@domdasthreads',
#  'bom',
#  'dia',
#  '@mcdonaldsbr',
#  'tudo',
#  'bem',
#  'ficamos',
#  'sabendo',
#  'que',
#  'vcs',
#  'apoiam',
#  'o',
#  'comunismo',
#  'aquela',
#  'ideologia',
#  'nefasta',
#  'que',
#  'torturou',
#  'e',
#  'mato…',
#  '@mcdonaldsbr',
#  'esse',
#  'é',
#  'o',
#  'padrão',
#  'agora',
#  'dos',
#  'lanches',
#  '@zanettils',
#  '@mcdonaldsbr',
#  'kkkkkkkkkkkkkkk',
#  'eu',
#  'fui',
#  'buscar',
#  'uma',
#  'maionese',
#  'na',
#  'cozinha',
#  'pq',
#  'ta',
#  'seco',
#  'seco',
#  'seco',
#  'sem',
#  'brincadeira',
#  'alguma',
#  '@zeppelinfour',
#  'mds',
#  'siim',
#  'eu',
#  'com',
#  'certeza',
#  'assino',
#  'e',
#  'apoio',
#  'o',
#  'milkshake',
#  'larry',
#  'aaaaaa',
#  '@mcdonaldsbr',
#  'vc',
#  'tá',
#  'perdendo',
#  'money',
#  'podia',
#  'ter',
#  'o',
#  'milkshake',
#  'larry',
#  '💅',
#  'rt',
#  '@drikarg1',
#  '@oiiuiz',
#  '@mcdonaldsbr',
#  'olha',
#  'não',
#  'sou',
#  'tão',
#  'inteligente',
#  'e',
#  'como',
#  'boa',
#  'tia',
#  'do',
#  'zap',
#  'caio',
#  'nas',
#  'bait',
#  'do',
#  'povo',
#  'kkkkk',
#  'mas',
#  'nesse',
#  'momento',
#  'len…',
#  '@slpnggiantspt',
#  '@mcdonaldsbr',
#  'mcdonald´s',
#  'faça',
#  'um',
#  'favor',
#  'suma',
#  'do',
#  'brasil',
#  'orgulho',
#  'do',
#  'luan',
#  'um',
#  'exemplo',
#  'que',
#  'dê',
#  'tudo',
#  'certo',
#  '🙏🏼❤',
#  'luan',
#  'pelo',
#  'pantanal',
#  '@cocacolabr',
#  '@americanascom',
#  '@skol',
#  '@amstelbrasil',
#  '@multishow',
#  '@picpay',
#  '@lojasrenner',
#  '@mcdonaldsbr',
#  '@burgerkingbr',
#  '@brahmacerveja',
#  '@amazonbr',
#  '@nike',
#  '@adidasbrasil',
#  '@nestleninho',
#  '@fanta',
#  '@redeglobo',
#  'rt',
#  '@flaviogordon',
#  '@mcdonaldsbr',
#  '@slpnggiantspt',
#  '@youtubebrasil',
#  'vocês',
#  'conhecem',
#  'o',
#  'obscuro',
#  'perfil',
#  '“sleeping',
#  'giants”',
#  'tratase',
#  'de',
#  'um',
#  'perfil',
#  'qu…',
#  'alô',
#  '@mcdonaldsbr',
#  'corre',
#  'aqui',
#  'estou',
#  'definindo',
#  'pessoas',
#  'baseados',
#  'nos',
#  'lanches',
#  'mereço',
#  'reconhecimento',
#  'do',
#  'mequi',
#  'uai',
#  '@mcdonaldsbr',
#  'acabou',
#  'hambúrguer',
#  'de',
#  'vocês',
#  'empresas',
#  'como',
#  '@uberbrasil',
#  '@ifood',
#  '@mcdonaldsbr',
#  'entre',
#  'outros',
#  'empinando',
#  'o',
#  'rabo',
#  'para',
#  'perfil',
#  'anônimo',
#  'que',
#  'manipula',
#  'o',
#  'mercado',
#  'em',
#  'nome',
#  'da',
#  'democracia',
#  'empresas',
#  'mequetrefes',
#  'não',
#  'importa',
#  'mais',
#  'o',
#  'que',
#  'faça',
#  '@slpnggiantspt',
#  'não',
#  'vão',
#  'derrotar',
#  'o',
#  'consevadorismo',
#  'mike',
#  'me',
#  'mandou',
#  'a',
#  'campanha',
#  'de',
#  '@mcdonaldsbr',
#  'logo',
#  'mais',
#  'verei',
#  '@mcdonaldsbr',
#  'e',
#  '@ifood',
#  'estão',
#  'de',
#  'parabéns',
#  'reclamei',
#  'do',
#  'pedido',
#  'péssimo',
#  'que',
#  'veio',
#  'do',
#  'mc',
#  'pois',
#  'tudo',
#  'estava',
#  'gelado',
#  'e',
#  'duro',
#  'e',
#  'eles',
#  'se',
#  'prontificaram',
#  'e',
#  'mandaram',
#  'outro',
#  'delicioso',
#  'parabéns',
#  '@mcdonaldsbr',
#  '@fepaesleme',
#  'beleza',
#  'mas',
#  'cade',
#  'o',
#  'travis',
#  'meal',
#  'eu',
#  'tô',
#  'numa',
#  'de',
#  'comer',
#  'mc',
#  'que',
#  'só',
#  'a',
#  'misericórdia',
#  'de',
#  'deus',
#  'só',
#  'queria',
#  'q',
#  'me',
#  'patrocinasse',
#  '@mcdonaldsbr',
#  '@mmaglobal',
#  'c/',
#  '@wazebrasil',
#  '@mcdonaldsbr',
#  '@agenciadpzt',
#  'transformando',
#  'a',
#  'experiência',
#  'do',
#  'consumidor',
#  'através',
#  'da',
#  'inovação',
#  '🤝',
#  'se',
#  'liga',
#  '@mcdonaldsbr',
#  'kd',
#  'o',
#  'lanche',
#  'do',
#  'travis',
#  'oii',
#  '@mcdonaldsbr',
#  'boa',
#  'tarde',
#  'o',
#  '@luansantana',
#  'está',
#  'com',
#  'um',
#  'projeto',
#  'para',
#  'ajudar',
#  'o',
#  'pantanal',
#  'há',
#  'dois',
#  'meses',
#  'o',
#  'projeto',
#  'está',
#  'pronto',
#  'e',
#  'a',
#  'procura',
#  'de',
#  'patrocínio/apoio',
#  'você',
#  'poderia',
#  'ajudar',
#  'mesmo',
#  'que',
#  'seja',
#  'um',
#  'tweet',
#  'sobre',
#  'a',
#  'causa',
#  'já',
#  'faria',
#  'a',
#  'diferença',
#  'o',
#  'pantanal',
#  'chama',
#  '@itzdeboraxxx',
#  '@dhsouza6',
#  '@mcdonaldsbr',
#  'vou',
#  'ai',
#  'vc',
#  'só',
#  'fica',
#  'no',
#  'telefone',
#  '@opredao',
#  '@mcdonaldsbr',
#  'vão',
#  'perder',
#  'esse',
#  'artista',
#  '@mcdonaldsbr',
#  'faça',
#  'alguma',
#  'coisa',
#  '🙏🏻😭',
#  '@fabiocatena',
#  '@mcdonaldsbr',
#  '@uberbrasil',
#  'engraçado',
#  'uma',
#  'vez',
#  'não',
#  'veio',
#  'um',
#  'item',
#  'informei',
#  'e',
#  'já',
#  'devolveram',
#  'automaticamente',
#  'o',
#  'valor',
#  'dele',
#  'totalmente',
#  'inspirado',
#  'nas',
#  'dicas',
#  'de',
#  'receita',
#  'da',
#  '@lariluana93',
#  'um',
#  'recado',
#  'para',
#  'o',
#  '@mcdonaldsbr',
#  'cês',
#  'tão',
#  'frito',
#  'na',
#  'minha',
#  'mão',
#  '😁😎',
#  '@tremmbarbie22',
#  '@mcdonaldsbr',
#  'sextouuuu',
#  'só',
#  'vamos',
#  'pedi',
#  '2',
#  'big',
#  'mac',
#  'e',
#  '2',
#  'batatas',
#  'média',
#  'veio',
#  'um',
#  'tasty',
#  'e',
#  'uma',
#  'batat',
#  'grande',
#  'poxa',
#  '@mcdonaldsbr',
#  'fiquei',
#  'aguada',
#  'no',
#  'big',
#  'mac',
#  '@mcdonaldsbr',
#  '@fepaesleme',
#  'pq',
#  'vcs',
#  'não',
#  'fazem',
#  'uma',
#  'edição',
#  'especial',
#  'de',
#  ...]

# %%
lista_palavras_train = pd.Series(todas_palavras_train)  
tabela_palavras_train_relativa = lista_palavras_train.value_counts(True)
tabela_palavras_train_relativa
# Out:
# @mcdonaldsbr    0.052298
# o               0.031876
# e               0.023738
# que             0.020723
# de              0.020497
#                   ...
# email           0.000075
# obscuro         0.000075
# muitas          0.000075
# acéfalo         0.000075
# razão           0.000075
# Length: 3297, dtype: float64

# %%
tabela_palavras_train_relativa.sum()
# Out:
# 1.0

# %%
# probFraseDado0 = 1
# probFraseDado1 = 1
# probFraseDado2 = 1
# probFraseDado3 = 1
# probFraseDado4 = 1

# for i in frase:
#     probFraseDado0 *= tabela_palavras_teste_relativa[i]
#     probFraseDado1 *= tabela_palavras_teste_relativa[i]
#     probFraseDado2 *= tabela_palavras_teste_relativa[i]
#     probFraseDado3 *= tabela_palavras_teste_relativa[i]
#     probFraseDado4 *= tabela_palavras_teste_relativa[i]

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Os trabalhos vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * Limpar: \n, :, ", ', (, ), etc SEM remover emojis
# * Corrigir separação de espaços entre palavras e emojis ou entre emojis e emojis
# * Propor outras limpezas e transformações que não afetem a qualidade da informação ou classificação
# * Criar categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante (3 categorias: C, mais categorias conta para B)
# * Explicar por que não posso usar o próprio classificador para gerar mais amostras de treinamento
# * Propor diferentes cenários para Naïve Bayes fora do contexto do projeto
# * Sugerir e explicar melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * Montar um dashboard que realiza análise de sentimento e visualiza estes dados

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
